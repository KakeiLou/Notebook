# %%
from Black_FutOpt import *
import tushare as ts

# %%
Black_call_value(6617, 6014.16, 0/365,(54/365), 0.033876, 0.259725)
# Out:
# 656.52911864310499

# %%
ts.get_h_data('IC1712')
# Out:
# [Getting data:]####
# Empty DataFrame
# Columns: []
# Index: []

# %%
4e236c895237ee1b7292cf32d871a151d703faded00a36b6be658755990fb0d7

# %%
ts.set_token('4e236c895237ee1b7292cf32d871a151d703faded00a36b6be658755990fb0d7')

# %%
mt = ts.Master()
df = mt.TradeCal(exchangeCD='XSHG', beginDate='20171109', endDate='20180710', field='calendarDate,isOpen,prevTradeDate')

# %%
df
# Out:
#     calendarDate  isOpen prevTradeDate
# 0     2017-11-09       1    2017-11-08
# 1     2017-11-10       1    2017-11-09
# 2     2017-11-11       0    2017-11-10
# 3     2017-11-12       0    2017-11-10
# 4     2017-11-13       1    2017-11-10
# 5     2017-11-14       1    2017-11-13
# 6     2017-11-15       1    2017-11-14
# 7     2017-11-16       1    2017-11-15
# 8     2017-11-17       1    2017-11-16
# 9     2017-11-18       0    2017-11-17
# 10    2017-11-19       0    2017-11-17
# 11    2017-11-20       1    2017-11-17
# 12    2017-11-21       1    2017-11-20
# 13    2017-11-22       1    2017-11-21
# 14    2017-11-23       1    2017-11-22
# 15    2017-11-24       1    2017-11-23
# 16    2017-11-25       0    2017-11-24
# 17    2017-11-26       0    2017-11-24
# 18    2017-11-27       1    2017-11-24
# 19    2017-11-28       1    2017-11-27
# 20    2017-11-29       1    2017-11-28
# 21    2017-11-30       1    2017-11-29
# 22    2017-12-01       1    2017-11-30
# ...

# %%
df[df.isOpen == 1]
# Out:
#     calendarDate  isOpen prevTradeDate
# 0     2017-11-09       1    2017-11-08
# 1     2017-11-10       1    2017-11-09
# 4     2017-11-13       1    2017-11-10
# 5     2017-11-14       1    2017-11-13
# 6     2017-11-15       1    2017-11-14
# 7     2017-11-16       1    2017-11-15
# 8     2017-11-17       1    2017-11-16
# 11    2017-11-20       1    2017-11-17
# 12    2017-11-21       1    2017-11-20
# 13    2017-11-22       1    2017-11-21
# 14    2017-11-23       1    2017-11-22
# 15    2017-11-24       1    2017-11-23
# 18    2017-11-27       1    2017-11-24
# 19    2017-11-28       1    2017-11-27
# 20    2017-11-29       1    2017-11-28
# 21    2017-11-30       1    2017-11-29
# 22    2017-12-01       1    2017-11-30
# 25    2017-12-04       1    2017-12-01
# 26    2017-12-05       1    2017-12-04
# 27    2017-12-06       1    2017-12-05
# 28    2017-12-07       1    2017-12-06
# 29    2017-12-08       1    2017-12-07
# 32    2017-12-11       1    2017-12-08
# ...
