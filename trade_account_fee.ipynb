# %%
import pandas as pd

# %%
df1 = pd.read_hdf('C:/Users/Administrator/Desktop/Work/data/CTAtrade_account/trade_detail_007738030022.h5')

# %%
df1
# Out:
#      instrument  order_no trade_time  direction  order_price  lots  turnover  \
# 0         M1705  10545298   10:05:32          0       2909.0     1   29090.0
# 1         M1705  10548973   10:05:59          1       2912.0     1   29120.0
# 2         RM705  01513316   10:31:32          0       2441.0     5  122050.0
# 3         M1705  10612069   10:42:27          0       2912.0     1   29120.0
# 4         M1705  10612494   10:42:45          0       2913.0     1   29130.0
# 5         M1705  10613334   10:43:10          0       2912.0     1   29120.0
# 6         M1705  10659448   10:59:45          1       2914.0     2   58280.0
# 7         M1705  10659449   10:59:45          1       2914.0     1   29140.0
# 8         RM705  01630287   11:01:03          1       2449.0     2   48980.0
# 9         RM705  01630519   11:01:05          1       2449.0     1   24490.0
# 10        RM705  01630521   11:01:05          1       2449.0     1   24490.0
# ...

# %%
df2 = pd.read_hdf('C:/Users/Administrator/Desktop/Work/data/CTAtrade_account/trade_detail_001810115002.h5')

# %%
df2
# Out:
#     instrument  order_no trade_time  direction  order_price  lots  turnover  \
# 0        C1709  10397523   13:31:28          1       1670.0     5   83500.0
# 1        C1709  10424539   13:42:18          1       1669.0     3   50070.0
# 2        MA709  01736313   13:47:54          0       2502.0     1   25020.0
# 3        MA709  01736315   13:47:54          0       2502.0     2   50040.0
# 4        MA709  01743943   13:49:44          0       2501.0     2   50020.0
# 5        C1709  10438422   13:50:38          0       1673.0     8  133840.0
# 6        L1709  30479260   13:52:29          0       9200.0     2   92000.0
# 7       RU1709  01716175   13:53:04          0      13560.0     1  135600.0
# 8        MA709  01772932   13:57:01          0       2501.0     3   75030.0
# 9        MA709  01791156   14:00:51          1       2496.0     1   24960.0
# 10      RU1709  01769795   14:05:35          1      13515.0     1  135150.0
# ...

# %%
df3 = pd.concat([df1,df2])

# %%
df3
# Out:
#     instrument  order_no trade_time  direction  order_price  lots  turnover  \
# 0        M1705  10545298   10:05:32          0       2909.0     1   29090.0
# 1        M1705  10548973   10:05:59          1       2912.0     1   29120.0
# 2        RM705  01513316   10:31:32          0       2441.0     5  122050.0
# 3        M1705  10612069   10:42:27          0       2912.0     1   29120.0
# 4        M1705  10612494   10:42:45          0       2913.0     1   29130.0
# 5        M1705  10613334   10:43:10          0       2912.0     1   29120.0
# 6        M1705  10659448   10:59:45          1       2914.0     2   58280.0
# 7        M1705  10659449   10:59:45          1       2914.0     1   29140.0
# 8        RM705  01630287   11:01:03          1       2449.0     2   48980.0
# 9        RM705  01630519   11:01:05          1       2449.0     1   24490.0
# 10       RM705  01630521   11:01:05          1       2449.0     1   24490.0
# ...

# %%
#sr1 = df3.instrument.str.rstrip('1234567890')

# %%
#sr2 = pd.Series(sr1.unique())

# %%
#sr2 = sr2.sort_values()
#sr2.to_excel('instruments.xlsx')

# %%
sr1 = df3.groupby(df3.real_trade_date).fee.sum()

# %%
df3 = df3.sort_values('real_trade_date')
df3
# Out:
#     instrument  order_no trade_time  direction  order_price  lots  turnover  \
# 0        M1705  10545298   10:05:32          0       2909.0     1   29090.0
# 13       P1705  10706475   11:22:25          0       6332.0     1   63320.0
# 12       RM705  01673866   11:10:48          0       2441.0     1   24410.0
# 11       RM705  01639663   11:03:24          1       2446.0     1   24460.0
# 10       RM705  01630521   11:01:05          1       2449.0     1   24490.0
# 9        RM705  01630519   11:01:05          1       2449.0     1   24490.0
# 15       P1705  10717070   13:30:03          0       6348.0     1   63480.0
# 8        RM705  01630287   11:01:03          1       2449.0     2   48980.0
# 6        M1705  10659448   10:59:45          1       2914.0     2   58280.0
# 5        M1705  10613334   10:43:10          0       2912.0     1   29120.0
# 3        M1705  10612069   10:42:27          0       2912.0     1   29120.0
# ...

# %%
df4 = df3[0:42827]
df4
# Out:
#     instrument  order_no trade_time  direction  order_price  lots  turnover  \
# 0        M1705  10545298   10:05:32          0       2909.0     1   29090.0
# 13       P1705  10706475   11:22:25          0       6332.0     1   63320.0
# 12       RM705  01673866   11:10:48          0       2441.0     1   24410.0
# 11       RM705  01639663   11:03:24          1       2446.0     1   24460.0
# 10       RM705  01630521   11:01:05          1       2449.0     1   24490.0
# 9        RM705  01630519   11:01:05          1       2449.0     1   24490.0
# 15       P1705  10717070   13:30:03          0       6348.0     1   63480.0
# 8        RM705  01630287   11:01:03          1       2449.0     2   48980.0
# 6        M1705  10659448   10:59:45          1       2914.0     2   58280.0
# 5        M1705  10613334   10:43:10          0       2912.0     1   29120.0
# 3        M1705  10612069   10:42:27          0       2912.0     1   29120.0
# ...

# %%
df4.to_csv('trade_style1.csv')

# %%
df5 = df3[42827:]

# %%
df5.to_csv('trade_style2.csv')

# %%
df5 = df5.sort_values(['instrument','real_trade_date','trade_time'])
df5
# Out:
#     instrument  order_no trade_time  direction  order_price  lots  turnover  \
# 37       A1709  10459121   13:33:03          0       3783.0     5  189150.0
# 41       A1709  10479753   13:45:42          1       3777.0     1   37770.0
# 40       A1709  10479752   13:45:42          1       3777.0     2   75540.0
# 43       A1709  10485957   13:50:46          1       3778.0     1   37780.0
# 44       A1709  10489357   13:53:48          0       3783.0     2   75660.0
# 45       A1709  10489419   13:53:54          0       3783.0     2   75660.0
# 81       A1709  10141587   23:03:15          1       3795.0     3  113850.0
# 82       A1709  10143663   23:05:06          1       3795.0     1   37950.0
# 83       A1709  10143691   23:05:07          1       3795.0     1   37950.0
# 180      A1709  10024163   21:16:41          1       3778.0     5  188900.0
# 185      A1709  10025522   21:18:51          1       3779.0     1   37790.0
# ...

# %%
df5.groupby(df5.lots).apply(lambda x : x[x.lots >1])
# Out:
#          instrument  order_no trade_time  direction  order_price  lots  \
# lots
# 2    40       A1709  10479752   13:45:42          1       3777.0     2
#      44       A1709  10489357   13:53:48          0       3783.0     2
#      45       A1709  10489419   13:53:54          0       3783.0     2
#      63       A1801  10048652   21:40:54          1       3869.0     2
#      71       A1801  10073321   22:04:29          1       3866.0     2
#      77       A1801  10091414   22:22:19          1       3858.0     2
#      271      A1801  10537980   14:20:07          1       3845.0     2
#      289      A1801  10029853   21:09:41          0       3857.0     2
#      292      A1801  10039938   21:16:11          1       3852.0     2
#      543      A1801  10644631   14:53:55          1       3846.0     2
#      546      A1801  10652049   14:56:36          1       3848.0     2
#      565      A1801  10017739   21:04:52          1       3866.0     2
# ...

# %%
df6 = df5[0:3]
df6
# Out:
#    instrument  order_no trade_time  direction  order_price  lots  turnover  \
# 37      A1709  10459121   13:33:03          0       3783.0     5  189150.0
# 41      A1709  10479753   13:45:42          1       3777.0     1   37770.0
# 40      A1709  10479752   13:45:42          1       3777.0     2   75540.0
#
#     open_close    fee  realized_pl real_trade_date
# 37           1  10.20        600.0      2017-07-24
# 41           0   2.04          0.0      2017-07-24
# 40           0   4.08          0.0      2017-07-24

# %%
df6.index
# Out:
# Int64Index([37, 41, 40], dtype='int64')

# %%
df6
# Out:
#   instrument  order_no trade_time  direction  order_price  lots  turnover  \
# 0      A1709  10459121   13:33:03          0       3783.0     5  189150.0
# 1      A1709  10479753   13:45:42          1       3777.0     1   37770.0
# 2      A1709  10479752   13:45:42          1       3777.0     2   75540.0
#
#    open_close    fee  realized_pl real_trade_date
# 0           1  10.20        600.0      2017-07-24
# 1           0   2.04          0.0      2017-07-24
# 2           0   4.08          0.0      2017-07-24

# %%
for i in range(len(df6)):
    if df6.loc[i].lots ==1:
        continue
    else:
        newlist = []
        for j in range(df6.loc[i].lots):
            newdf = df6[0:1].copy()
            newdf.lots = 1
            print(newdf)
# Out:
#   instrument  order_no trade_time  direction  order_price  lots  turnover  \
# 0      A1709  10459121   13:33:03          0       3783.0     1  189150.0
#
#    open_close   fee  realized_pl real_trade_date
# 0           1  10.2        600.0      2017-07-24
#   instrument  order_no trade_time  direction  order_price  lots  turnover  \
# 0      A1709  10459121   13:33:03          0       3783.0     1  189150.0
#
#    open_close   fee  realized_pl real_trade_date
# 0           1  10.2        600.0      2017-07-24
#   instrument  order_no trade_time  direction  order_price  lots  turnover  \
# 0      A1709  10459121   13:33:03          0       3783.0     1  189150.0
#
#    open_close   fee  realized_pl real_trade_date
# 0           1  10.2        600.0      2017-07-24
#   instrument  order_no trade_time  direction  order_price  lots  turnover  \
# 0      A1709  10459121   13:33:03          0       3783.0     1  189150.0
#
#    open_close   fee  realized_pl real_trade_date
# ...

# %%
df7= df6[0:1].copy()
df7.lots =1 
df7
# Out:
#   instrument  order_no trade_time  direction  order_price  lots  turnover  \
# 0      A1709  10459121   13:33:03          0       3783.0     1  189150.0
#
#    open_close   fee  realized_pl real_trade_date
# 0           1  10.2        600.0      2017-07-24

# %%
# Out:
#   instrument  order_no trade_time  direction  order_price  lots  turnover  \
# 0      A1709  10459121   13:33:03          0       3783.0     1  189150.0
#
#    open_close   fee  realized_pl real_trade_date
# 0           1  10.2        600.0      2017-07-24
