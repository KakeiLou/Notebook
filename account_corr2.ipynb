# %%
import pandas as pd
df = pd.read_hdf('C:\\Users\\Administrator\\Desktop\\Work\\data\\hsi_data\\positive_corr.h5')
df
# Out:
#        hsi_index      rate
# A0054   0.459183  0.650522
# A0075   0.434223  0.422912
# A0117   0.725166  0.814256
# A0155   0.727154  0.821569
# A0167   0.794393  0.856633
# A0225   0.795461  0.827648
# A0300   0.780153  0.563919
# A0328   0.520180  0.857679
# A0391   0.931857  0.846332
# A0484   0.510163  0.760329
# A0508   0.676610  0.560231
# A0530   0.549116  0.468063
# A0548   0.410041  0.730581
# A0617   0.749537  0.533075
# A0634   0.907447  0.480645
# A0687   0.988215  0.792273
# A0690   0.896953  0.969781
# A0694   0.648984  0.967117
# A0718   0.939260  0.587402
# A0747   0.501875  0.797956
# A0749   0.603845  0.751678
# A0766   0.578619  0.517563
# A0768   0.644951  0.703978
# A0776   0.801598  0.807272
# A0781   0.975689  0.761277
# A0809   0.510654  0.467402
# A0823   0.946581  0.867169
# A0858   0.732474  0.546950
# A0882   0.776316  0.979594
# A0902   0.659736  0.707513
# ...          ...       ...
# A1011   0.799669  0.864176
# A1019   0.412638  0.431427
# ...
