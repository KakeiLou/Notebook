# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,2*np.pi, 100)
plt.plot(x,np.sin(x))
plt.show()

# %%
x = np.linspace(0,2*np.pi,50)
plt.plot(x,np.sin(x),x,np.sin(2*x))
plt.show()

# %%
x = np.linspace(0,2*np.pi,50)
plt.plot(x,np.sin(x),'r-o',
        x,np.cos(x),'b--')
plt.show()

# %%
x = np.linspace(0,2*np.pi,50)
plt.subplot(2,2,2)
plt.plot(x,np.sin(x),'r')
plt.subplot(2,2,1)
plt.plot(x,np.cos(x),'g')
plt.show()

# %%
x = np.linspace(0,2*np.pi,30)
y = np.sin(x)
plt.scatter(x,y)
plt.show()

# %%
# %matplotlib inline

# %%
mpl.rcParams['xtick.labelsize'] =30
mpl.rcParams['ytick.labelsize'] =25

# %%
np.random.seed(17)

# %%
x = np.linspace(0, 20, 50)

# %%
y = 7*np.sin(x) + 0.6*x**3
y_data = y + np.random.normal(scale=0.5,size =50)

# %%
plt.figure('fakedata')

# %%
plt.plot(x, y_data,'.')

# %%
plt.figure('fakemodel')

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,'r',lw=3)

# %%
plt.scatter(x, y_data)

# %%
plt.figure('fakedata & fakemodel')

# %%
plt.plot(x, y, 'r', lw =0.5)

# %%
plt.scatter(x, y_data)

# %%
plt.show()
