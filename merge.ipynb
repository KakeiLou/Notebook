# %%
import pandas as pd

# %%
df1 = pd.read_hdf('C:\\Users\\Administrator\\Desktop\\Work\\data\\hsi_data\\hsi_with_allprofit.h5')
df2 = pd.read_hdf('C:\\Users\\Administrator\\Desktop\\Work\\data\\hsi_data\\all_account_profit.h5')
df2
# Out:
#            profit                                                         \
# account     A0001  A0002  A0003  A0004  A0005  A0006  A0007  A0008 A0009
# 2013-05-02  173.0  166.0   98.0   42.0  -77.0  130.0  319.0  141.0  11.0
# 2013-05-03  323.0  -38.0   75.0   86.0  104.0   35.0  -80.0 -135.0  20.0
# 2013-05-06  478.0   95.0   51.0   21.0    NaN   99.0  -43.0    NaN   NaN
# 2013-05-07 -223.0  -16.0  -46.0    NaN    NaN  102.0    NaN    NaN -55.0
# 2013-05-08  -57.0  -28.0  -34.0   10.0    NaN  185.0  117.0  -17.0   NaN
# 2013-05-09  -43.0   97.0  -54.0   45.0    NaN  156.0  -64.0    NaN  -3.0
# 2013-05-10   23.0 -111.0 -116.0  -40.0    NaN   29.0   44.0    NaN   5.0
# 2013-05-13  122.0   82.0  143.0  -30.0    NaN   42.0  253.0    NaN  24.0
# 2013-05-14 -245.0  -58.0  -87.0   85.0    NaN   48.0 -242.0    NaN -18.0
# 2013-05-15    NaN  108.0    NaN   23.0    NaN  -76.0  -31.0    NaN -47.0
# 2013-05-16    NaN   49.0    NaN   47.0    NaN    NaN  340.0    NaN   NaN
# ...

# %%
df1
# Out:
#             hsi_index      rate  date_all_profit
# date2
# 2013-05-02   22668.30       NaN           1322.0
# 2013-05-03   22689.96  0.000956           1364.0
# 2013-05-06   22915.09  0.009922           2261.0
# 2013-05-07   23047.09  0.005760             81.0
# 2013-05-08   23244.35  0.008559            591.0
# 2013-05-09   23211.48 -0.001414           1104.0
# 2013-05-10   23321.22  0.004728           -625.0
# 2013-05-13   22989.81 -0.014211            407.0
# 2013-05-14   22930.28 -0.002589             77.0
# 2013-05-15   23044.24  0.004970            210.0
# 2013-05-16   23082.68  0.001668           1133.0
# 2013-05-20   23493.03  0.017777           -558.0
# 2013-05-21   23366.37 -0.005391             99.0
# 2013-05-22   23261.08 -0.004506           -263.0
# 2013-05-23   22669.68 -0.025424          -1348.0
# 2013-05-24   22618.67 -0.002250            944.0
# 2013-05-27   22686.05  0.002979           1683.0
# 2013-05-28   22924.25  0.010500            592.0
# ...

# %%
df1.index
# Out:
# DatetimeIndex(['2013-05-02', '2013-05-03', '2013-05-06', '2013-05-07',
#                '2013-05-08', '2013-05-09', '2013-05-10', '2013-05-13',
#                '2013-05-14', '2013-05-15',
#                ...
#                '2015-12-16', '2015-12-17', '2015-12-18', '2015-12-21',
#                '2015-12-22', '2015-12-23', '2015-12-24', '2015-12-28',
#                '2015-12-29', '2015-12-30'],
#               dtype='datetime64[ns]', name='date2', length=658, freq=None)

# %%
df2.index
# Out:
# DatetimeIndex(['2013-05-02', '2013-05-03', '2013-05-06', '2013-05-07',
#                '2013-05-08', '2013-05-09', '2013-05-10', '2013-05-13',
#                '2013-05-14', '2013-05-15',
#                ...
#                '2015-12-16', '2015-12-17', '2015-12-18', '2015-12-21',
#                '2015-12-22', '2015-12-23', '2015-12-24', '2015-12-28',
#                '2015-12-29', '2015-12-30'],
#               dtype='datetime64[ns]', length=658, freq=None)

# %%
df3 = df1.join(df2)
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py:551: UserWarning: merging between different levels can give an unintended result (1 levels on the left, 2 on the right)
#   warnings.warn(msg, UserWarning)

# %%
df3
# Out:
#             hsi_index      rate  date_all_profit  (profit, A0001)  \
# date2
# 2013-05-02   22668.30       NaN           1322.0            173.0
# 2013-05-03   22689.96  0.000956           1364.0            323.0
# 2013-05-06   22915.09  0.009922           2261.0            478.0
# 2013-05-07   23047.09  0.005760             81.0           -223.0
# 2013-05-08   23244.35  0.008559            591.0            -57.0
# 2013-05-09   23211.48 -0.001414           1104.0            -43.0
# 2013-05-10   23321.22  0.004728           -625.0             23.0
# 2013-05-13   22989.81 -0.014211            407.0            122.0
# 2013-05-14   22930.28 -0.002589             77.0           -245.0
# 2013-05-15   23044.24  0.004970            210.0              NaN
# 2013-05-16   23082.68  0.001668           1133.0              NaN
# 2013-05-20   23493.03  0.017777           -558.0              NaN
# 2013-05-21   23366.37 -0.005391             99.0              NaN
# ...

# %%
df3.to_excel('index_profit.xlsx',sheet_name='sheet1')

# %%
df3.to_csv('hsiprofit.csv')

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()

# %%
df3.plot()

# %%
df3.plot

# %%
result = df1.join(df2, on='key')
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py:551: UserWarning: merging between different levels can give an unintended result (1 levels on the left, 2 on the right)
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5239)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5085)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20405)()
#
# ...

# %%
df2.index
# Out:
# DatetimeIndex(['2013-05-02', '2013-05-03', '2013-05-06', '2013-05-07',
#                '2013-05-08', '2013-05-09', '2013-05-10', '2013-05-13',
#                '2013-05-14', '2013-05-15',
#                ...
#                '2015-12-16', '2015-12-17', '2015-12-18', '2015-12-21',
#                '2015-12-22', '2015-12-23', '2015-12-24', '2015-12-28',
#                '2015-12-29', '2015-12-30'],
#               dtype='datetime64[ns]', length=658, freq=None)

# %%
df2.describe()
# Out:
#              profit                                                    \
# account       A0001       A0002        A0003        A0004       A0005
# count     10.000000  466.000000    96.000000   466.000000  206.000000
# mean      44.100000    8.899142    -4.604167     3.173820    6.640777
# std      232.297439  141.377937   146.182473    97.127197  196.087803
# min     -245.000000 -853.000000 -1022.000000 -1115.000000 -730.000000
# 25%      -96.750000  -29.000000   -45.250000   -31.750000  -91.500000
# 50%      -10.000000   26.500000    19.500000    20.500000   18.500000
# 75%      160.250000   78.000000    63.750000    46.000000   97.750000
# max      478.000000  457.000000   344.000000   497.000000  678.000000
#
#                                                                      ...   \
# account       A0006       A0007       A0008       A0009       A0010  ...
# count    103.000000   42.000000    3.000000  412.000000  144.000000  ...
# ...

# %%
df2.rename(columns={'profit A0001':'A0001'}, inplace= True)

# %%
df2.columns
# Out:
# MultiIndex(levels=[['profit'], ['A0001', 'A0002', 'A0003', 'A0004', 'A0005', 'A0006', 'A0007', 'A0008', 'A0009', 'A0010', 'A0011', 'A0012', 'A0013', 'A0014', 'A0015', 'A0016', 'A0017', 'A0018', 'A0019', 'A0020', 'A0021', 'A0022', 'A0023', 'A0024', 'A0025', 'A0026', 'A0027', 'A0028', 'A0029', 'A0030', 'A0031', 'A0032', 'A0033', 'A0034', 'A0035', 'A0036', 'A0037', 'A0038', 'A0039', 'A0040', 'A0041', 'A0042', 'A0043', 'A0044', 'A0045', 'A0046', 'A0047', 'A0048', 'A0049', 'A0050', 'A0051', 'A0052', 'A0053', 'A0054', 'A0055', 'A0056', 'A0057', 'A0058', 'A0059', 'A0060', 'A0061', 'A0062', 'A0063', 'A0064', 'A0065', 'A0066', 'A0067', 'A0068', 'A0069', 'A0070', 'A0071', 'A0072', 'A0073', 'A0074', 'A0075', 'A0076', 'A0077', 'A0078', 'A0079', 'A0080', 'A0081', 'A0082', 'A0083', 'A0084', 'A0085', 'A0086', 'A0087', 'A0088', 'A0089', 'A0090', 'A0091', 'A0092', 'A0093', 'A0094', 'A0095', 'A0096', 'A0097', 'A0098', 'A0099', 'A0100', 'A0101', 'A0102', 'A0103', 'A0104', 'A0105', 'A0106', 'A0107', 'A0
# ...

# %%
df2['profit']
# Out:
# account     A0001  A0002  A0003  A0004  A0005  A0006  A0007  A0008  A0009  \
# 2013-05-02  173.0  166.0   98.0   42.0  -77.0  130.0  319.0  141.0   11.0
# 2013-05-03  323.0  -38.0   75.0   86.0  104.0   35.0  -80.0 -135.0   20.0
# 2013-05-06  478.0   95.0   51.0   21.0    NaN   99.0  -43.0    NaN    NaN
# 2013-05-07 -223.0  -16.0  -46.0    NaN    NaN  102.0    NaN    NaN  -55.0
# 2013-05-08  -57.0  -28.0  -34.0   10.0    NaN  185.0  117.0  -17.0    NaN
# 2013-05-09  -43.0   97.0  -54.0   45.0    NaN  156.0  -64.0    NaN   -3.0
# 2013-05-10   23.0 -111.0 -116.0  -40.0    NaN   29.0   44.0    NaN    5.0
# 2013-05-13  122.0   82.0  143.0  -30.0    NaN   42.0  253.0    NaN   24.0
# 2013-05-14 -245.0  -58.0  -87.0   85.0    NaN   48.0 -242.0    NaN  -18.0
# 2013-05-15    NaN  108.0    NaN   23.0    NaN  -76.0  -31.0    NaN  -47.0
# 2013-05-16    NaN   49.0    NaN   47.0    NaN    NaN  340.0    NaN    NaN
# 2013-05-20    NaN    NaN    NaN  -27.0    NaN    NaN  171.0    NaN   -2.0
# ...

# %%
df2
# Out:
# account     A0001  A0002  A0003  A0004  A0005  A0006  A0007  A0008  A0009  \
# 2013-05-02  173.0  166.0   98.0   42.0  -77.0  130.0  319.0  141.0   11.0
# 2013-05-03  323.0  -38.0   75.0   86.0  104.0   35.0  -80.0 -135.0   20.0
# 2013-05-06  478.0   95.0   51.0   21.0    NaN   99.0  -43.0    NaN    NaN
# 2013-05-07 -223.0  -16.0  -46.0    NaN    NaN  102.0    NaN    NaN  -55.0
# 2013-05-08  -57.0  -28.0  -34.0   10.0    NaN  185.0  117.0  -17.0    NaN
# 2013-05-09  -43.0   97.0  -54.0   45.0    NaN  156.0  -64.0    NaN   -3.0
# 2013-05-10   23.0 -111.0 -116.0  -40.0    NaN   29.0   44.0    NaN    5.0
# 2013-05-13  122.0   82.0  143.0  -30.0    NaN   42.0  253.0    NaN   24.0
# 2013-05-14 -245.0  -58.0  -87.0   85.0    NaN   48.0 -242.0    NaN  -18.0
# 2013-05-15    NaN  108.0    NaN   23.0    NaN  -76.0  -31.0    NaN  -47.0
# 2013-05-16    NaN   49.0    NaN   47.0    NaN    NaN  340.0    NaN    NaN
# 2013-05-20    NaN    NaN    NaN  -27.0    NaN    NaN  171.0    NaN   -2.0
# ...

# %%
df2.to_excel('index_profit2.xlsx',sheet_name='sheet1')

# %%
df5 = df1.join(df2)

# %%
df5
# Out:
#             hsi_index      rate  date_all_profit  A0001  A0002  A0003  A0004  \
# date2
# 2013-05-02   22668.30       NaN           1322.0  173.0  166.0   98.0   42.0
# 2013-05-03   22689.96  0.000956           1364.0  323.0  -38.0   75.0   86.0
# 2013-05-06   22915.09  0.009922           2261.0  478.0   95.0   51.0   21.0
# 2013-05-07   23047.09  0.005760             81.0 -223.0  -16.0  -46.0    NaN
# 2013-05-08   23244.35  0.008559            591.0  -57.0  -28.0  -34.0   10.0
# 2013-05-09   23211.48 -0.001414           1104.0  -43.0   97.0  -54.0   45.0
# 2013-05-10   23321.22  0.004728           -625.0   23.0 -111.0 -116.0  -40.0
# 2013-05-13   22989.81 -0.014211            407.0  122.0   82.0  143.0  -30.0
# 2013-05-14   22930.28 -0.002589             77.0 -245.0  -58.0  -87.0   85.0
# 2013-05-15   23044.24  0.004970            210.0    NaN  108.0    NaN   23.0
# 2013-05-16   23082.68  0.001668           1133.0    NaN   49.0    NaN   47.0
# ...

# %%
df5.to_excel('index_profit2.xlsx',sheet_name='sheet1')
