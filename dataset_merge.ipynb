# %%
import pandas as pd

# %%
df0 = pd.read_hdf('C://Users//Administrator//Desktop//mergehsi//FinishedDataset/amplitude.h5')

# %%
df1 = pd.read_hdf('C://Users//Administrator//Desktop//mergehsi//FinishedDataset/amplitudeDuration.h5')

# %%
df2 = pd.read_hdf('C://Users//Administrator//Desktop//mergehsi//FinishedDataset/amplitudeSlope.h5')

# %%
df3 = pd.read_hdf('C://Users//Administrator//Desktop//mergehsi//FinishedDataset/biggestGain.h5')

# %%
df4 = pd.read_hdf('C://Users//Administrator//Desktop//mergehsi//FinishedDataset/maxdrawdown.h5')

# %%
df5 = pd.read_hdf('C://Users//Administrator//Desktop//mergehsi//FinishedDataset/realizedVolatility.h5')

# %%
df6 = pd.read_hdf('C://Users//Administrator//Desktop//mergehsi//FinishedDataset/returnSkewness.h5')

# %%
df7 = pd.read_hdf('C://Users//Administrator//Desktop//mergehsi//FinishedDataset/rtn_1min_std.h5')

# %%
df8 = pd.read_hdf('C://Users//Administrator//Desktop//mergehsi//FinishedDataset/rtn_5mins_std.h5')

# %%
df9 = pd.read_hdf('C://Users//Administrator//Desktop//mergehsi//FinishedDataset/sidewayDuration.h5')

# %%
df10 = pd.read_hdf('C://Users//Administrator//Desktop//mergehsi//FinishedDataset/trendIndex.h5')

# %%
df11 = pd.read_hdf('C://Users//Administrator//Desktop//mergehsi//FinishedDataset/vol_sum.h5')

# %%
merge_all = pd.concat([df0,df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11],axis=1,join_axes=[df0.index])
merge_all
# Out:
#             amplitude  Max_Time  Min_Time amplitudeDuration  Max_Time  \
# 2013-05-02      568.0  11:01:59  10:51:59          00:10:00  11:01:59
# 2013-05-03      625.0  10:00:59  13:35:57          03:34:58  10:00:59
# 2013-05-06      559.0  09:15:59  10:43:58          01:27:59  09:15:59
# 2013-05-07      585.0  16:10:58  09:26:58          06:44:00  16:10:58
# 2013-05-08      512.0  15:37:59  09:50:56          05:47:03  15:37:59
# 2013-05-09      547.0  09:20:59  09:25:56          00:04:57  09:20:59
# 2013-05-10      553.0  15:34:59  15:44:57          00:09:58  15:34:59
# 2013-05-13      715.0  09:15:59  14:53:59          05:38:00  09:15:59
# 2013-05-14      671.0  09:28:59  13:02:58          03:33:59  09:28:59
# 2013-05-15      552.0  13:20:58  15:44:59          02:24:01  13:20:58
# 2013-05-16      628.0  11:23:58  09:25:59          01:57:59  11:23:58
# 2013-05-20      630.0  11:05:58  09:14:01          01:51:57  11:05:58
# ...

# %%
merge_all.drop('Max_Time',axis=1,inplace=True)

# %%
merge_all.drop('Min_Time',axis=1,inplace=True)

# %%
merge_all.drop('amplitudeDuration',axis=1,inplace=True)

# %%
merge_all.drop('hour',axis=1,inplace=True)

# %%
merge_all.drop('mins',axis=1,inplace=True)

# %%
merge_all
# Out:
#             amplitude  amplitude  secs  Duration_mins  amplitudeSlope  \
# 2013-05-02      568.0      568.0     0      10.000000       56.800000
# 2013-05-03      625.0      625.0    58     214.966667        2.907428
# 2013-05-06      559.0      559.0    59      87.983333        6.353476
# 2013-05-07      585.0      585.0     0     404.000000        1.448020
# 2013-05-08      512.0      512.0     3     347.050000        1.475292
# 2013-05-09      547.0      547.0    57       4.950000      110.505051
# 2013-05-10      553.0      553.0    58       9.966667       55.484950
# 2013-05-13      715.0      715.0     0     338.000000        2.115385
# 2013-05-14      671.0      671.0    59     213.983333        3.135758
# 2013-05-15      552.0      552.0     1     144.016667        3.832890
# 2013-05-16      628.0      628.0    59     117.983333        5.322786
# 2013-05-20      630.0      630.0    57     111.950000        5.627512
# ...

# %%
merge_all.drop('secs',axis=1,inplace=True)

# %%
merge_all
# Out:
#             amplitude  amplitude  Duration_mins  amplitudeSlope   up2here  \
# 2013-05-02      568.0      568.0      10.000000       56.800000  0.014093
# 2013-05-03      625.0      625.0     214.966667        2.907428  0.019325
# 2013-05-06      559.0      559.0      87.983333        6.353476  0.018187
# 2013-05-07      585.0      585.0     404.000000        1.448020  0.025476
# 2013-05-08      512.0      512.0     347.050000        1.475292  0.014060
# 2013-05-09      547.0      547.0       4.950000      110.505051  0.012167
# 2013-05-10      553.0      553.0       9.966667       55.484950  0.017937
# 2013-05-13      715.0      715.0     338.000000        2.115385  0.013406
# 2013-05-14      671.0      671.0     213.983333        3.135758  0.014908
# 2013-05-15      552.0      552.0     144.016667        3.832890  0.016553
# 2013-05-16      628.0      628.0     117.983333        5.322786  0.016170
# 2013-05-20      630.0      630.0     111.950000        5.627512  0.024038
# ...

# %%
merge_all.drop('up2here',axis=1,inplace=True)

# %%
merge_all
# Out:
#             amplitude  amplitude  Duration_mins  amplitudeSlope   up2here  \
# 2013-05-02      568.0      568.0      10.000000       56.800000  0.014093
# 2013-05-03      625.0      625.0     214.966667        2.907428  0.019325
# 2013-05-06      559.0      559.0      87.983333        6.353476  0.018187
# 2013-05-07      585.0      585.0     404.000000        1.448020  0.025476
# 2013-05-08      512.0      512.0     347.050000        1.475292  0.014060
# 2013-05-09      547.0      547.0       4.950000      110.505051  0.012167
# 2013-05-10      553.0      553.0       9.966667       55.484950  0.017937
# 2013-05-13      715.0      715.0     338.000000        2.115385  0.013406
# 2013-05-14      671.0      671.0     213.983333        3.135758  0.014908
# 2013-05-15      552.0      552.0     144.016667        3.832890  0.016553
# 2013-05-16      628.0      628.0     117.983333        5.322786  0.016170
# 2013-05-20      630.0      630.0     111.950000        5.627512  0.024038
# ...

# %%
merge_all.columns = ['000','amplitude','amplitudeDuration','amplitudeSlope','biggestGain','maxdrawdown','realizedVol','returnSkewness','rtn_1min_std','rtn_5min_std','sidewayDuration','trendIndex','vol_sum']

# %%
merge_all.drop('000',axis=1,inplace=True)

# %%
merge_all
# Out:
#             amplitude  amplitudeDuration  amplitudeSlope  biggestGain  \
# 2013-05-02      568.0          10.000000       56.800000     0.014093
# 2013-05-03      625.0         214.966667        2.907428     0.019325
# 2013-05-06      559.0          87.983333        6.353476     0.018187
# 2013-05-07      585.0         404.000000        1.448020     0.025476
# 2013-05-08      512.0         347.050000        1.475292     0.014060
# 2013-05-09      547.0           4.950000      110.505051     0.012167
# 2013-05-10      553.0           9.966667       55.484950     0.017937
# 2013-05-13      715.0         338.000000        2.115385     0.013406
# 2013-05-14      671.0         213.983333        3.135758     0.014908
# 2013-05-15      552.0         144.016667        3.832890     0.016553
# 2013-05-16      628.0         117.983333        5.322786     0.016170
# 2013-05-20      630.0         111.950000        5.627512     0.024038
# ...

# %%
merge_all.to_hdf('merge_dataset.h5','hsi')

# %%
merge_all.amplitude.idxmin()
# Out:
# datetime.date(2013, 10, 28)

# %%
merge_all.index = pd.to_datetime(merge_all.index)

# %%
merge_all['2013-05-02':'2013-10-28']
# Out:
#             amplitude  amplitudeDuration  amplitudeSlope  biggestGain  \
# 2013-05-02      568.0          10.000000       56.800000     0.014093
# 2013-05-03      625.0         214.966667        2.907428     0.019325
# 2013-05-06      559.0          87.983333        6.353476     0.018187
# 2013-05-07      585.0         404.000000        1.448020     0.025476
# 2013-05-08      512.0         347.050000        1.475292     0.014060
# 2013-05-09      547.0           4.950000      110.505051     0.012167
# 2013-05-10      553.0           9.966667       55.484950     0.017937
# 2013-05-13      715.0         338.000000        2.115385     0.013406
# 2013-05-14      671.0         213.983333        3.135758     0.014908
# 2013-05-15      552.0         144.016667        3.832890     0.016553
# 2013-05-16      628.0         117.983333        5.322786     0.016170
# 2013-05-20      630.0         111.950000        5.627512     0.024038
# ...
