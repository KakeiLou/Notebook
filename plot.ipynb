# %%
import pandas as pd
df = pd.read_csv('C:\\Users\\Administrator\\Desktop\\Work\\data\\hsi_data\\index_profit.csv')

# %%
df
# Out:
#           date2  hsi_index      rate  date_all_profit  ('profit', 'A0001')  \
# 0    2013-05-02   22668.30       NaN           1322.0                173.0
# 1    2013-05-03   22689.96  0.000956           1364.0                323.0
# 2    2013-05-06   22915.09  0.009922           2261.0                478.0
# 3    2013-05-07   23047.09  0.005760             81.0               -223.0
# 4    2013-05-08   23244.35  0.008559            591.0                -57.0
# 5    2013-05-09   23211.48 -0.001414           1104.0                -43.0
# 6    2013-05-10   23321.22  0.004728           -625.0                 23.0
# 7    2013-05-13   22989.81 -0.014211            407.0                122.0
# 8    2013-05-14   22930.28 -0.002589             77.0               -245.0
# 9    2013-05-15   23044.24  0.004970            210.0                  NaN
# 10   2013-05-16   23082.68  0.001668           1133.0                  NaN
# ...

# %%
df.index = df.date2

# %%
df.index
# Out:
# Index(['2013-05-02', '2013-05-03', '2013-05-06', '2013-05-07', '2013-05-08',
#        '2013-05-09', '2013-05-10', '2013-05-13', '2013-05-14', '2013-05-15',
#        ...
#        '2015-12-16', '2015-12-17', '2015-12-18', '2015-12-21', '2015-12-22',
#        '2015-12-23', '2015-12-24', '2015-12-28', '2015-12-29', '2015-12-30'],
#       dtype='object', name='date2', length=658)

# %%
df
# Out:
#                  date2  hsi_index      rate  date_all_profit  \
# date2
# 2013-05-02  2013-05-02   22668.30       NaN           1322.0
# 2013-05-03  2013-05-03   22689.96  0.000956           1364.0
# 2013-05-06  2013-05-06   22915.09  0.009922           2261.0
# 2013-05-07  2013-05-07   23047.09  0.005760             81.0
# 2013-05-08  2013-05-08   23244.35  0.008559            591.0
# 2013-05-09  2013-05-09   23211.48 -0.001414           1104.0
# 2013-05-10  2013-05-10   23321.22  0.004728           -625.0
# 2013-05-13  2013-05-13   22989.81 -0.014211            407.0
# 2013-05-14  2013-05-14   22930.28 -0.002589             77.0
# 2013-05-15  2013-05-15   23044.24  0.004970            210.0
# 2013-05-16  2013-05-16   23082.68  0.001668           1133.0
# 2013-05-20  2013-05-20   23493.03  0.017777           -558.0
# 2013-05-21  2013-05-21   23366.37 -0.005391             99.0
# 2013-05-22  2013-05-22   23261.08 -0.004506           -263.0
# ...

# %%
df.index = pd.to_datetime(df.index)

# %%
df.index
# Out:
# DatetimeIndex(['2013-05-02', '2013-05-03', '2013-05-06', '2013-05-07',
#                '2013-05-08', '2013-05-09', '2013-05-10', '2013-05-13',
#                '2013-05-14', '2013-05-15',
#                ...
#                '2015-12-16', '2015-12-17', '2015-12-18', '2015-12-21',
#                '2015-12-22', '2015-12-23', '2015-12-24', '2015-12-28',
#                '2015-12-29', '2015-12-30'],
#               dtype='datetime64[ns]', name='date2', length=658, freq=None)

# %%
del df['date2']

# %%
df
# Out:
#             hsi_index      rate  date_all_profit  ('profit', 'A0001')  \
# date2
# 2013-05-02   22668.30       NaN           1322.0                173.0
# 2013-05-03   22689.96  0.000956           1364.0                323.0
# 2013-05-06   22915.09  0.009922           2261.0                478.0
# 2013-05-07   23047.09  0.005760             81.0               -223.0
# 2013-05-08   23244.35  0.008559            591.0                -57.0
# 2013-05-09   23211.48 -0.001414           1104.0                -43.0
# 2013-05-10   23321.22  0.004728           -625.0                 23.0
# 2013-05-13   22989.81 -0.014211            407.0                122.0
# 2013-05-14   22930.28 -0.002589             77.0               -245.0
# 2013-05-15   23044.24  0.004970            210.0                  NaN
# 2013-05-16   23082.68  0.001668           1133.0                  NaN
# 2013-05-20   23493.03  0.017777           -558.0                  NaN
# ...

# %%
df.to_hdf('index_profit.h5','hsi')

# %%
df1 = pd.read_excel('C:\\Users\\Administrator\\Desktop\\Work\\data\\hsi_data\\index_profit.xlsx')

# %%
df1
# Out:
#          date2  hsi_index      rate  date_all_profit  ('profit', 'A0001')  \
# 0   2013-05-02   22668.30       NaN             1322                173.0
# 1   2013-05-03   22689.96  0.000956             1364                323.0
# 2   2013-05-06   22915.09  0.009922             2261                478.0
# 3   2013-05-07   23047.09  0.005760               81               -223.0
# 4   2013-05-08   23244.35  0.008559              591                -57.0
# 5   2013-05-09   23211.48 -0.001414             1104                -43.0
# 6   2013-05-10   23321.22  0.004728             -625                 23.0
# 7   2013-05-13   22989.81 -0.014211              407                122.0
# 8   2013-05-14   22930.28 -0.002589               77               -245.0
# 9   2013-05-15   23044.24  0.004970              210                  NaN
# 10  2013-05-16   23082.68  0.001668             1133                  NaN
# 11  2013-05-20   23493.03  0.017777             -558                  NaN
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.rate.plot()

# %%
df.rate.plot(color = 'b')
df.date_all_profit.plot(color = 'r')
plt.legend(loc = 'best')

# %%
df.rate.corr(df.date_all_profit)
# Out:
# -0.14302934698595221

# %%
ddf = pd.read_excel('C:\\Users\\Administrator\\Desktop\\Work\\data\\hsi_data\\index_profit2.xlsx')
ddf
# Out:
#          date2  hsi_index      rate  date_all_profit  A0001  A0002  A0003  \
# 0   2013-05-02   22668.30       NaN             1322  173.0  166.0   98.0
# 1   2013-05-03   22689.96  0.000956             1364  323.0  -38.0   75.0
# 2   2013-05-06   22915.09  0.009922             2261  478.0   95.0   51.0
# 3   2013-05-07   23047.09  0.005760               81 -223.0  -16.0  -46.0
# 4   2013-05-08   23244.35  0.008559              591  -57.0  -28.0  -34.0
# 5   2013-05-09   23211.48 -0.001414             1104  -43.0   97.0  -54.0
# 6   2013-05-10   23321.22  0.004728             -625   23.0 -111.0 -116.0
# 7   2013-05-13   22989.81 -0.014211              407  122.0   82.0  143.0
# 8   2013-05-14   22930.28 -0.002589               77 -245.0  -58.0  -87.0
# 9   2013-05-15   23044.24  0.004970              210    NaN  108.0    NaN
# 10  2013-05-16   23082.68  0.001668             1133    NaN   49.0    NaN
# 11  2013-05-20   23493.03  0.017777             -558    NaN    NaN    NaN
# ...
