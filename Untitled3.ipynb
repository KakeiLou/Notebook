# %%
import pandas as pd
df = pd.read_hdf('C://Users//Administrator//Desktop//hsi_data//his_simplified.h5')

# %%
df
# Out:
#                     instrument type  month  trade_date trade_time    price  \
# b'trade_datetime'
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# ...

# %%
df2 = df.head()

# %%
df2
# Out:
#                     instrument type  month  trade_date trade_time    price  \
# b'trade_datetime'
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
#
#                      vol
# b'trade_datetime'
# 2014-01-02 09:14:00    2
# 2014-01-02 09:14:00    2
# 2014-01-02 09:14:00    8
# 2014-01-02 09:14:00   11
# 2014-01-02 09:14:00   10

# %%
df2.index
# Out:
# DatetimeIndex(['2014-01-02 09:14:00', '2014-01-02 09:14:00',
#                '2014-01-02 09:14:00', '2014-01-02 09:14:00',
#                '2014-01-02 09:14:00'],
#               dtype='datetime64[ns]', name=b'trade_datetime', freq=None)

# %%
df2.index.date
# Out:
# array([datetime.date(2014, 1, 2), datetime.date(2014, 1, 2),
#        datetime.date(2014, 1, 2), datetime.date(2014, 1, 2),
#        datetime.date(2014, 1, 2)], dtype=object)

# %%
df2.index.time
# Out:
# array([datetime.time(9, 14), datetime.time(9, 14), datetime.time(9, 14),
#        datetime.time(9, 14), datetime.time(9, 14)], dtype=object)

# %%
print (df2.columns)
# Out:
# Index(['instrument', 'type', 'month', 'trade_date', 'trade_time', 'price',
#        'vol'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['instrument', 'type', 'month', 'trade_date', 'trade_time', 'price',
#        'vol'],
#       dtype='object')

# %%
df2.index.month
# Out:
# Int64Index([1, 1, 1, 1, 1], dtype='int64', name=b'trade_datetime')

# %%
df2[df2.index.month ==1]
# Out:
#                     instrument type  month  trade_date trade_time    price  \
# b'trade_datetime'
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
#
#                      vol
# b'trade_datetime'
# 2014-01-02 09:14:00    2
# 2014-01-02 09:14:00    2
# 2014-01-02 09:14:00    8
# 2014-01-02 09:14:00   11
# 2014-01-02 09:14:00   10

# %%
df2[df2.vol ==2]
# Out:
#                     instrument type  month  trade_date trade_time    price  \
# b'trade_datetime'
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
#
#                      vol
# b'trade_datetime'
# 2014-01-02 09:14:00    2
# 2014-01-02 09:14:00    2

# %% [markdown]
# df2.index.time

# %%
df2.index.time
# Out:
# array([datetime.time(9, 14), datetime.time(9, 14), datetime.time(9, 14),
#        datetime.time(9, 14), datetime.time(9, 14)], dtype=object)

# %%
df2.index.hour
# Out:
# Int64Index([9, 9, 9, 9, 9], dtype='int64', name=b'trade_datetime')

# %%
df2.ix[df2.vol>8,:7]
# Out:
#                     instrument type  month  trade_date trade_time    price  \
# b'trade_datetime'
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
#
#                      vol
# b'trade_datetime'
# 2014-01-02 09:14:00   11
# 2014-01-02 09:14:00   10
