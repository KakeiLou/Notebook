# %%
import pandas as pd
df = pd.read_hdf('C:\\Users\\Administrator\\Desktop\\Work\\data\\trade_account\\tradeaccount_merged.h5')
df
# Out:
#       instrument  order_no trade_time  direction  order_price  lots  turnover  \
# 0          M1705  10545298   10:05:32          0       2909.0     1   29090.0
# 1          M1705  10548973   10:05:59          1       2912.0     1   29120.0
# 2          RM705  01513316   10:31:32          0       2441.0     5  122050.0
# 3          M1705  10612069   10:42:27          0       2912.0     1   29120.0
# 4          M1705  10612494   10:42:45          0       2913.0     1   29130.0
# 5          M1705  10613334   10:43:10          0       2912.0     1   29120.0
# 6          M1705  10659448   10:59:45          1       2914.0     2   58280.0
# 7          M1705  10659449   10:59:45          1       2914.0     1   29140.0
# 8          RM705  01630287   11:01:03          1       2449.0     2   48980.0
# 9          RM705  01630519   11:01:05          1       2449.0     1   24490.0
# 10         RM705  01630521   11:01:05          1       2449.0     1   24490.0
# ...

# %%
df2 = df[df.open_close == 0]

# %%
df2
# Out:
#       instrument  order_no trade_time  direction  order_price  lots  turnover  \
# 0          M1705  10545298   10:05:32          0       2909.0     1   29090.0
# 2          RM705  01513316   10:31:32          0       2441.0     5  122050.0
# 3          M1705  10612069   10:42:27          0       2912.0     1   29120.0
# 4          M1705  10612494   10:42:45          0       2913.0     1   29130.0
# 5          M1705  10613334   10:43:10          0       2912.0     1   29120.0
# 12         RM705  01673866   11:10:48          0       2441.0     1   24410.0
# 13         P1705  10706475   11:22:25          0       6332.0     1   63320.0
# 14         RM705  01718548   11:27:20          0       2448.0     1   24480.0
# 15         P1705  10717070   13:30:03          0       6348.0     1   63480.0
# 16         P1705  10717084   13:30:03          0       6348.0     1   63480.0
# 17         P1705  10719102   13:30:24          0       6346.0     1   63460.0
# ...

# %%
df3 = df[df.open_close == 1]
df3
# Out:
#       instrument  order_no trade_time  direction  order_price  lots  turnover  \
# 1          M1705  10548973   10:05:59          1       2912.0     1   29120.0
# 6          M1705  10659448   10:59:45          1       2914.0     2   58280.0
# 7          M1705  10659449   10:59:45          1       2914.0     1   29140.0
# 8          RM705  01630287   11:01:03          1       2449.0     2   48980.0
# 9          RM705  01630519   11:01:05          1       2449.0     1   24490.0
# 10         RM705  01630521   11:01:05          1       2449.0     1   24490.0
# 11         RM705  01639663   11:03:24          1       2446.0     1   24460.0
# 25         TA705  01869120   13:48:16          1       5268.0     1   26340.0
# 26         TA705  01871372   13:48:26          1       5272.0     1   26360.0
# 27         TA705  01871373   13:48:26          1       5272.0     1   26360.0
# 28         Y1705  10783183   13:50:26          1       7178.0     2  143560.0
# ...

# %%
df3['num'] = 1
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df3
# Out:
#       instrument  order_no trade_time  direction  order_price  lots  turnover  \
# 1          M1705  10548973   10:05:59          1       2912.0     1   29120.0
# 6          M1705  10659448   10:59:45          1       2914.0     2   58280.0
# 7          M1705  10659449   10:59:45          1       2914.0     1   29140.0
# 8          RM705  01630287   11:01:03          1       2449.0     2   48980.0
# 9          RM705  01630519   11:01:05          1       2449.0     1   24490.0
# 10         RM705  01630521   11:01:05          1       2449.0     1   24490.0
# 11         RM705  01639663   11:03:24          1       2446.0     1   24460.0
# 25         TA705  01869120   13:48:16          1       5268.0     1   26340.0
# 26         TA705  01871372   13:48:26          1       5272.0     1   26360.0
# 27         TA705  01871373   13:48:26          1       5272.0     1   26360.0
# 28         Y1705  10783183   13:50:26          1       7178.0     2  143560.0
# ...

# %%
sr1 = df3.groupby(df3.instrument).num.sum()

# %%
sr1
# Out:
# instrument
# A1705      456
# A1709      544
# A1801      152
# AL1705      31
# AL1710       2
# BU1705       2
# BU1706     313
# BU1709     312
# BU1712     100
# BU1801       4
# C1705      129
# C1709      625
# C1801      133
# CF705      263
# CF709      144
# CF801       83
# CS1705     987
# CS1709     821
# CS1801     194
# CU1702      60
# CU1703      25
# CU1704      53
# CU1705      38
# CU1706       3
# CU1707      20
# CU1708      35
# CU1709       7
# CU1710       4
# CU1711       5
# FG705      644
#           ...
# RM705     1959
# RM709     1748
# RM801      281
# RU1705     159
# RU1709      98
# RU1801      53
# SM709      373
# SM801       42
# SR705      369
# SR709      210
# SR801       18
# TA705     1291
# TA709      595
# TA801      457
# V1709       34
# V1801       34
# Y1705      401
# Y1709       73
# Y1801      221
# ZC705        1
# ZN1702      17
# ZN1703      21
# ZN1704      27
# ZN1705      41
# ZN1706      19
# ZN1707      13
# ZN1708      13
# ...

# %%
df3[df3.instrument='SR801']
# Out:
#       instrument  order_no trade_time  direction  order_price  lots  turnover  \
# 48872      SR801  00194758   21:26:00          0       6149.0     1   61490.0
# 48898      SR801  00373105   22:10:24          0       6140.0     1   61400.0
# 49052      SR801  00128852   21:12:41          0       6127.0     1   61270.0
# 49181      SR801  01591676   10:51:05          0       6125.0     1   61250.0
# 49182      SR801  01597989   10:53:07          0       6130.0     1   61300.0
# 49183      SR801  01597990   10:53:07          0       6130.0     1   61300.0
# 49184      SR801  01597991   10:53:07          0       6130.0     1   61300.0
# 49208      SR801  02060543   14:37:24          0       6096.0     1   60960.0
# 49230      SR801  00508629   22:21:51          0       6111.0     1   61110.0
# 49231      SR801  00544172   22:27:34          0       6128.0     1   61280.0
# 49232      SR801  00567741   22:29:00          0       6158.0     1   61580.0
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sr1.plot(kind='pie', subplots=True, figsize=(8, 4))  
sr1.plot(kind='pie', subplots=True,autopct='%.2f',figsize=(8, 4)) #显示百分比  
plt.show()

# %%
sr2 = sr1.sort_values(ascending=False)
sr2
# Out:
# instrument
# MA705     2393
# RM705     1959
# RM709     1748
# M1705     1584
# MA709     1549
# TA705     1291
# CS1705     987
# CS1709     821
# M1709      811
# FG709      735
# FG705      644
# C1709      625
# TA709      595
# A1709      544
# P1705      518
# TA801      457
# A1705      456
# JD1705     447
# Y1705      401
# SM709      373
# SR705      369
# RB1705     361
# L1705      331
# BU1706     313
# BU1709     312
# RM801      281
# M1801      267
# CF705      263
# RB1710     257
# L1709      231
#           ...
# V1801       34
# PP1801      32
# AL1705      31
# ZN1704      27
# CU1703      25
# NI1801      25
# JM1801      23
# ZN1703      21
# CU1707      20
# ZN1706      19
# SR801       18
# ZN1702      17
# ZN1710      16
# ZN1708      13
# ZN1707      13
# NI1709      12
# CU1709       7
# ZN1712       5
# CU1711       5
# JM1705       5
# JD1708       4
# BU1801       4
# CU1710       4
# J1705        3
# CU1706       3
# BU1705       2
# AL1710       2
# ...

# %%
sr3 = sr2[sr2>200]

# %%
#sr3.plot(kind='pie', subplots=True, figsize=(8, 8))  
sr2.plot(kind='pie', subplots=True,autopct='%.2f',figsize=(10, 10)) #显示百分比  
plt.show()

# %%
sr2.index
# Out:
# Index(['MA705', 'RM705', 'RM709', 'M1705', 'MA709', 'TA705', 'CS1705',
#        'CS1709', 'M1709', 'FG709', 'FG705', 'C1709', 'TA709', 'A1709', 'P1705',
#        'TA801', 'A1705', 'JD1705', 'Y1705', 'SM709', 'SR705', 'RB1705',
#        'L1705', 'BU1706', 'BU1709', 'RM801', 'M1801', 'CF705', 'RB1710',
#        'L1709', 'Y1801', 'PP1709', 'SR709', 'MA801', 'CS1801', 'P1709',
#        'RU1705', 'A1801', 'P1801', 'CF709', 'C1801', 'JD1709', 'C1705',
#        'RB1801', 'OI801', 'BU1712', 'PP1705', 'RU1709', 'FG801', 'CF801',
#        'Y1709', 'NI1705', 'I1801', 'CU1702', 'JD1801', 'RU1801', 'CU1704',
#        'ZN1709', 'L1801', 'SM801', 'ZN1705', 'CU1705', 'I1705', 'I1709',
#        'CU1708', 'V1709', 'V1801', 'PP1801', 'AL1705', 'ZN1704', 'CU1703',
#        'NI1801', 'JM1801', 'ZN1703', 'CU1707', 'ZN1706', 'SR801', 'ZN1702',
#        'ZN1710', 'ZN1708', 'ZN1707', 'NI1709', 'CU1709', 'ZN1712', 'CU1711',
#        'JM1705', 'JD1708', 'BU1801', 'CU1710', 'J1705', 'CU1706', 'BU1705',
# ...

# %%
sr2.to_csv('instrument1.csv')

# %%
#sr3.plot(kind='pie', subplots=True, figsize=(8, 8))  
sr3.plot(kind='pie', subplots=True,autopct='%.2f',figsize=(10, 10)) #显示百分比  
plt.show()

# %%
sr2.index.str.get(0)
# Out:
# Index(['T', 'R', 'M', 'Y', 'M', 'M', 'C', 'A', 'P', 'C', 'R', 'S', 'O', 'B',
#        'F', 'C', 'R', 'I', 'L', 'T', 'R', 'F', 'R', 'C', 'S', 'J', 'V', 'P',
#        'C', 'M', 'Z', 'J', 'A', 'N', 'J', 'S', 'Z', 'L', 'R', 'B', 'P', 'P',
#        'C', 'Z', 'C', 'B', 'V', 'A'],
#       dtype='object', name='instrument')

# %%
df4 = pd.read_excel('C:\\Users\\Administrator\\Desktop\\Work\\data\\trade_account\\index.xlsx')

# %%
df4
# Out:
#    Ins
# 0   MA
# 1   RM
# 2   RM
# 3    M
# 4   MA
# 5   TA
# 6   CS
# 7   CS
# 8    M
# 9   FG
# 10  FG
# 11   C
# 12  TA
# 13   A
# 14   P
# 15  TA
# 16   A
# 17  JD
# 18   Y
# 19  SM
# 20  SR
# 21  RB
# 22   L
# 23  BU
# 24  BU
# 25  RM
# 26   M
# 27  CF
# 28  RB
# 29   L
# ..  ..
# 66   V
# 67  PP
# 68  AL
# 69  ZN
# 70  CU
# 71  NI
# 72  JM
# 73  ZN
# 74  CU
# 75  ZN
# 76  SR
# 77  ZN
# 78  ZN
# 79  ZN
# 80  ZN
# 81  NI
# 82  CU
# 83  ZN
# 84  CU
# 85  JM
# 86  JD
# 87  BU
# 88  CU
# 89   J
# 90  CU
# 91  BU
# 92  AL
# 93  ZC
# 94  JM
# 95   J
#
# [96 rows x 1 columns]

# %%
sr2.index = df4.Ins

# %%
sr2
# Out:
# Ins
# MA    2393
# RM    1959
# RM    1748
# M     1584
# MA    1549
# TA    1291
# CS     987
# CS     821
# M      811
# FG     735
# FG     644
# C      625
# TA     595
# A      544
# P      518
# TA     457
# A      456
# JD     447
# Y      401
# SM     373
# SR     369
# RB     361
# L      331
# BU     313
# BU     312
# RM     281
# M      267
# CF     263
# RB     257
# L      231
#       ...
# V       34
# PP      32
# AL      31
# ZN      27
# CU      25
# NI      25
# JM      23
# ZN      21
# CU      20
# ZN      19
# SR      18
# ZN      17
# ZN      16
# ZN      13
# ZN      13
# NI      12
# CU       7
# ZN       5
# CU       5
# JM       5
# JD       4
# BU       4
# CU       4
# J        3
# CU       3
# BU       2
# AL       2
# ZC       1
# JM       1
# J        1
# Name: num, Length: 96, dtype: int64

# %%
sr4 = sr2.groupby(sr2.index).sum()

# %%
sr4
# Out:
# Ins
# A     1152
# AL      33
# BU     731
# C      887
# CF     490
# CS    2002
# CU     250
# FG    1472
# I      138
# J        4
# JD     641
# JM      29
# L      613
# M     2662
# MA    4144
# NI     105
# OI     107
# P      840
# PP     352
# RB     728
# RM    3988
# RU     310
# SM     415
# SR     597
# TA    2343
# V       68
# Y      695
# ZC       1
# ZN     224
# Name: num, dtype: int64

# %%
sr4 = sr4.sort_values(ascending=False)
sr4
# Out:
# Ins
# MA    4144
# RM    3988
# M     2662
# TA    2343
# CS    2002
# FG    1472
# A     1152
# C      887
# P      840
# BU     731
# RB     728
# Y      695
# JD     641
# L      613
# SR     597
# CF     490
# SM     415
# PP     352
# RU     310
# CU     250
# ZN     224
# I      138
# OI     107
# NI     105
# V       68
# AL      33
# JM      29
# J        4
# ZC       1
# Name: num, dtype: int64

# %%
len(sr4)
# Out:
# 29

# %%
sr4.plot(kind='pie', subplots =True, autopct = '%.2f', figsize=(10,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000000F3DEB00>], dtype=object)

# %%
df3[df3.instrument == 'CU1709']
# Out:
#       instrument  order_no trade_time  direction  order_price  lots  turnover  \
# 40192     CU1709  01515923   13:37:18          1      46920.0     1  234600.0
# 40195     CU1709  01568699   13:41:46          1      46870.0     1  234350.0
# 40369     CU1709  01204098   10:38:30          1      46840.0     1  234200.0
# 40370     CU1709  01204156   10:38:31          1      46840.0     1  234200.0
# 40417     CU1709  01476107   13:39:43          1      46830.0     1  234150.0
# 40422     CU1709  01570281   13:51:46          1      46840.0     1  234200.0
# 40454     CU1709  01962895   14:53:44          1      47110.0     1  235550.0
#
#        open_close  fee  realized_pl real_trade_date  num
# 40192           1  0.0       -150.0      2017-07-10    1
# 40195           1  0.0       -500.0      2017-07-10    1
# 40369           1  0.0        200.0      2017-07-11    1
# 40370           1  0.0        150.0      2017-07-11    1
# 40417           1  0.0       -200.0      2017-07-11    1
# ...

# %%
sr5 = sr4[sr4>1000]
sr5.plot(kind= 'barh', color = 'g', alpha = 0.8)
