# %%
import pandas as pd

# %%
df = pd.read_hdf('C:\\Users\\Administrator\\Desktop\\\mergehsi\\his_simplified.h5')
df
# Out:
#                     instrument type  month  trade_date trade_time    price  \
# b'trade_datetime'
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# ...

# %%
df.index.rename('trade_datetime', inplace = True)
df.index
# Out:
# DatetimeIndex(['2014-01-02 09:14:00', '2014-01-02 09:14:00',
#                '2014-01-02 09:14:00', '2014-01-02 09:14:00',
#                '2014-01-02 09:14:00', '2014-01-02 09:14:00',
#                '2014-01-02 09:14:00', '2014-01-02 09:14:00',
#                '2014-01-02 09:14:00', '2014-01-02 09:14:00',
#                ...
#                '2015-11-30 16:14:58', '2015-11-30 16:14:58',
#                '2015-11-30 16:14:58', '2015-11-30 16:14:58',
#                '2015-11-30 16:14:58', '2015-11-30 16:14:58',
#                '2015-11-30 16:14:58', '2015-11-30 16:14:58',
#                '2015-11-30 16:14:59', '2015-11-30 16:14:59'],
#               dtype='datetime64[ns]', name='trade_datetime', length=22925593, freq=None)

# %%
df2.index
# Out:
# DatetimeIndex(['2013-05-02 09:14:00', '2013-05-02 09:14:00',
#                '2013-05-02 09:14:00', '2013-05-02 09:14:00',
#                '2013-05-02 09:14:00', '2013-05-02 09:14:00',
#                '2013-05-02 09:14:00', '2013-05-02 09:14:00',
#                '2013-05-02 09:14:00', '2013-05-02 09:14:00',
#                ...
#                '2013-12-31 11:59:58', '2013-12-31 11:59:58',
#                '2013-12-31 11:59:58', '2013-12-31 11:59:58',
#                '2013-12-31 11:59:58', '2013-12-31 11:59:58',
#                '2013-12-31 11:59:59', '2013-12-31 11:59:59',
#                '2013-12-31 11:59:59', '2013-12-31 11:59:59'],
#               dtype='datetime64[ns]', name='trade_datetime', length=7859462, freq=None)

# %%
df2 = pd.read_hdf('C:\\Users\\Administrator\\Desktop\\\mergehsi\\his_simplified2.h5')
df2
# Out:
#                     instrument type   month  trade_date trade_time    price  \
# trade_datetime
# 2013-05-02 09:14:00        HSI    F  1305.0  2013-05-02   09:14:00  22574.0
# 2013-05-02 09:14:00        HSI    F  1305.0  2013-05-02   09:14:00  22574.0
# 2013-05-02 09:14:00        HSI    F  1305.0  2013-05-02   09:14:00  22574.0
# 2013-05-02 09:14:00        HSI    F  1305.0  2013-05-02   09:14:00  22574.0
# 2013-05-02 09:14:00        HSI    F  1305.0  2013-05-02   09:14:00  22574.0
# 2013-05-02 09:14:00        HSI    F  1305.0  2013-05-02   09:14:00  22574.0
# 2013-05-02 09:14:00        HSI    F  1305.0  2013-05-02   09:14:00  22574.0
# 2013-05-02 09:14:00        HSI    F  1305.0  2013-05-02   09:14:00  22574.0
# 2013-05-02 09:14:00        HSI    F  1305.0  2013-05-02   09:14:00  22574.0
# 2013-05-02 09:14:00        HSI    F  1305.0  2013-05-02   09:14:00  22574.0
# 2013-05-02 09:14:00        HSI    F  1305.0  2013-05-02   09:14:00  22574.0
# ...

# %%
df2.month.astype(int)
# Out:
# trade_datetime
# 2013-05-02 09:14:00    1305
# 2013-05-02 09:14:00    1305
# 2013-05-02 09:14:00    1305
# 2013-05-02 09:14:00    1305
# 2013-05-02 09:14:00    1305
# 2013-05-02 09:14:00    1305
# 2013-05-02 09:14:00    1305
# 2013-05-02 09:14:00    1305
# 2013-05-02 09:14:00    1305
# 2013-05-02 09:14:00    1305
# 2013-05-02 09:14:00    1305
# 2013-05-02 09:14:00    1305
# 2013-05-02 09:14:00    1305
# 2013-05-02 09:14:00    1305
# 2013-05-02 09:14:00    1305
# 2013-05-02 09:14:00    1305
# 2013-05-02 09:14:00    1305
# 2013-05-02 09:14:00    1305
# 2013-05-02 09:14:00    1305
# 2013-05-02 09:14:00    1305
# 2013-05-02 09:14:00    1305
# 2013-05-02 09:14:00    1305
# 2013-05-02 09:14:00    1305
# 2013-05-02 09:14:00    1305
# 2013-05-02 09:14:00    1305
# 2013-05-02 09:14:00    1305
# 2013-05-02 09:14:00    1305
# 2013-05-02 09:14:00    1305
# 2013-05-02 09:14:00    1305
# 2013-05-02 09:14:00    1305
#                        ...
# 2013-12-31 11:59:55    1401
# ...

# %%
df2.month = df2.month.astype(int)

# %%
df2.vol = df2.vol.astype(int)
df2
# Out:
#                     instrument type  month  trade_date trade_time    price  \
# trade_datetime
# 2013-05-02 09:14:00        HSI    F   1305  2013-05-02   09:14:00  22574.0
# 2013-05-02 09:14:00        HSI    F   1305  2013-05-02   09:14:00  22574.0
# 2013-05-02 09:14:00        HSI    F   1305  2013-05-02   09:14:00  22574.0
# 2013-05-02 09:14:00        HSI    F   1305  2013-05-02   09:14:00  22574.0
# 2013-05-02 09:14:00        HSI    F   1305  2013-05-02   09:14:00  22574.0
# 2013-05-02 09:14:00        HSI    F   1305  2013-05-02   09:14:00  22574.0
# 2013-05-02 09:14:00        HSI    F   1305  2013-05-02   09:14:00  22574.0
# 2013-05-02 09:14:00        HSI    F   1305  2013-05-02   09:14:00  22574.0
# 2013-05-02 09:14:00        HSI    F   1305  2013-05-02   09:14:00  22574.0
# 2013-05-02 09:14:00        HSI    F   1305  2013-05-02   09:14:00  22574.0
# 2013-05-02 09:14:00        HSI    F   1305  2013-05-02   09:14:00  22574.0
# ...

# %%
df3 = df2.append(df)

# %%
df3
# Out:
#                     instrument type  month  trade_date trade_time    price  \
# trade_datetime
# 2013-05-02 09:14:00        HSI    F   1305  2013-05-02   09:14:00  22574.0
# 2013-05-02 09:14:00        HSI    F   1305  2013-05-02   09:14:00  22574.0
# 2013-05-02 09:14:00        HSI    F   1305  2013-05-02   09:14:00  22574.0
# 2013-05-02 09:14:00        HSI    F   1305  2013-05-02   09:14:00  22574.0
# 2013-05-02 09:14:00        HSI    F   1305  2013-05-02   09:14:00  22574.0
# 2013-05-02 09:14:00        HSI    F   1305  2013-05-02   09:14:00  22574.0
# 2013-05-02 09:14:00        HSI    F   1305  2013-05-02   09:14:00  22574.0
# 2013-05-02 09:14:00        HSI    F   1305  2013-05-02   09:14:00  22574.0
# 2013-05-02 09:14:00        HSI    F   1305  2013-05-02   09:14:00  22574.0
# 2013-05-02 09:14:00        HSI    F   1305  2013-05-02   09:14:00  22574.0
# 2013-05-02 09:14:00        HSI    F   1305  2013-05-02   09:14:00  22574.0
# ...

# %%
df3.to_hdf('merge_HSI','hsi')
