# %%
import pandas as pd
df = pd.read_hdf('C:\\Users\\Administrator\\Desktop\\Work\\data\\account\\account_data_sumprofit.h5')

# %%
df
# Out:
#                     account product  buy_sell  take_price  \
# 2013-05-02 09:15:05   A0002   HSIK3         2     22565.0
# 2013-05-02 09:15:12   A0003   HSIK3         2     22560.0
# 2013-05-02 09:15:53   A0004   HSIK3         2     22554.0
# 2013-05-02 09:15:55   A0005   HSIK3         1     22553.0
# 2013-05-02 09:16:21   A0001   HSIK3         2     22524.0
# 2013-05-02 09:17:08   A0006   HSIK3         1     22535.0
# 2013-05-02 09:18:56   A0007   HSIK3         1     22528.0
# 2013-05-02 09:19:49   A0008   HSIK3         2     22527.0
# 2013-05-02 09:22:39   A0004   HSIK3         2     22513.0
# 2013-05-02 09:22:47   A0009   HSIK3         2     22515.0
# 2013-05-02 09:23:07   A0010   HSIK3         1     22540.0
# 2013-05-02 09:24:09   A0009   HSIK3         2     22552.0
# 2013-05-02 09:24:45   A0011   HSIK3         2     22543.0
# 2013-05-02 09:25:00   A0012   HSIK3         2     22549.0
# 2013-05-02 09:26:24   A0007   HSIK3         1     22542.0
# ...

# %%
df['2014-05-30']
# Out:
#                     account product  buy_sell  take_price  \
# 2014-05-30 09:15:07   A0632   HSIM4         2     22924.0
# 2014-05-30 09:15:07   A0704   HSIM4         1     22925.0
# 2014-05-30 09:15:10   A0369   HSIM4         2     22924.0
# 2014-05-30 09:15:11   A0723   HSIM4         2     22925.0
# 2014-05-30 09:15:25   A0481   HSIM4         2     22928.0
# 2014-05-30 09:15:28   A0683   HSIM4         1     22933.0
# 2014-05-30 09:15:43   A0739   HSIM4         1     22951.0
# 2014-05-30 09:15:44   A0302   HSIM4         2     22950.0
# 2014-05-30 09:15:49   A0704   HSIM4         1     22949.0
# 2014-05-30 09:15:55   A0095   HSIM4         2     22942.0
# 2014-05-30 09:16:03   A0632   HSIM4         2     22938.0
# 2014-05-30 09:16:09   A0613   HSIM4         2     22939.0
# 2014-05-30 09:16:12   A0800   HSIM4         1     22941.0
# 2014-05-30 09:16:48   A0704   HSIM4         1     22929.0
# 2014-05-30 09:16:50   A0741   HSIM4         1     22930.0
# ...

# %%
df.index.date
# Out:
# array([datetime.date(2013, 5, 2), datetime.date(2013, 5, 2),
#        datetime.date(2013, 5, 2), ..., datetime.date(2015, 12, 30),
#        datetime.date(2015, 12, 30), datetime.date(2015, 12, 30)], dtype=object)

# %%
df1 = pd.read_hdf('C:\\Users\\Administrator\\Desktop\\Work\\data\\hsi_data\\hsi_rate.h5')
df1
# Out:
#             hsi_index      rate
# date2
# 2013-5-2     22668.30       NaN
# 2013-5-3     22689.96  0.000956
# 2013-5-6     22915.09  0.009922
# 2013-5-7     23047.09  0.005760
# 2013-5-8     23244.35  0.008559
# 2013-5-9     23211.48 -0.001414
# 2013-5-10    23321.22  0.004728
# 2013-5-13    22989.81 -0.014211
# 2013-5-14    22930.28 -0.002589
# 2013-5-15    23044.24  0.004970
# 2013-5-16    23082.68  0.001668
# 2013-5-20    23493.03  0.017777
# 2013-5-21    23366.37 -0.005391
# 2013-5-22    23261.08 -0.004506
# 2013-5-23    22669.68 -0.025424
# 2013-5-24    22618.67 -0.002250
# 2013-5-27    22686.05  0.002979
# 2013-5-28    22924.25  0.010500
# 2013-5-29    22554.93 -0.016110
# 2013-5-30    22484.31 -0.003131
# 2013-5-31    22392.16 -0.004098
# 2013-6-3     22282.19 -0.004911
# 2013-6-4     22285.52  0.000149
# 2013-6-5     22069.24 -0.009705
# 2013-6-6     21838.43 -0.010458
# 2013-6-7     21575.26 -0.012051
# 2013-6-10    21615.09  0.001846
# 2013-6-11    21354.66 -0.012049
# ...

# %%
df1.index = pd.to_datetime(df1.index)

# %%
df1.index.date
# Out:
# array([datetime.date(2013, 5, 2), datetime.date(2013, 5, 3),
#        datetime.date(2013, 5, 6), datetime.date(2013, 5, 7),
#        datetime.date(2013, 5, 8), datetime.date(2013, 5, 9),
#        datetime.date(2013, 5, 10), datetime.date(2013, 5, 13),
#        datetime.date(2013, 5, 14), datetime.date(2013, 5, 15),
#        datetime.date(2013, 5, 16), datetime.date(2013, 5, 20),
#        datetime.date(2013, 5, 21), datetime.date(2013, 5, 22),
#        datetime.date(2013, 5, 23), datetime.date(2013, 5, 24),
#        datetime.date(2013, 5, 27), datetime.date(2013, 5, 28),
#        datetime.date(2013, 5, 29), datetime.date(2013, 5, 30),
#        datetime.date(2013, 5, 31), datetime.date(2013, 6, 3),
#        datetime.date(2013, 6, 4), datetime.date(2013, 6, 5),
#        datetime.date(2013, 6, 6), datetime.date(2013, 6, 7),
#        datetime.date(2013, 6, 10), datetime.date(2013, 6, 11),
#        datetime.date(2013, 6, 13), datetime.date(2013, 6, 14),
# ...

# %%
df
# Out:
#                     account product  buy_sell  take_price  \
# 2013-05-02 09:15:05   A0002   HSIK3         2     22565.0
# 2013-05-02 09:15:12   A0003   HSIK3         2     22560.0
# 2013-05-02 09:15:53   A0004   HSIK3         2     22554.0
# 2013-05-02 09:15:55   A0005   HSIK3         1     22553.0
# 2013-05-02 09:16:21   A0001   HSIK3         2     22524.0
# 2013-05-02 09:17:08   A0006   HSIK3         1     22535.0
# 2013-05-02 09:18:56   A0007   HSIK3         1     22528.0
# 2013-05-02 09:19:49   A0008   HSIK3         2     22527.0
# 2013-05-02 09:22:39   A0004   HSIK3         2     22513.0
# 2013-05-02 09:22:47   A0009   HSIK3         2     22515.0
# 2013-05-02 09:23:07   A0010   HSIK3         1     22540.0
# 2013-05-02 09:24:09   A0009   HSIK3         2     22552.0
# 2013-05-02 09:24:45   A0011   HSIK3         2     22543.0
# 2013-05-02 09:25:00   A0012   HSIK3         2     22549.0
# 2013-05-02 09:26:24   A0007   HSIK3         1     22542.0
# ...

# %%
df
# Out:
#                     account product  buy_sell  take_price  \
# 2013-05-02 09:15:05   A0002   HSIK3         2     22565.0
# 2013-05-02 09:15:12   A0003   HSIK3         2     22560.0
# 2013-05-02 09:15:53   A0004   HSIK3         2     22554.0
# 2013-05-02 09:15:55   A0005   HSIK3         1     22553.0
# 2013-05-02 09:16:21   A0001   HSIK3         2     22524.0
# 2013-05-02 09:17:08   A0006   HSIK3         1     22535.0
# 2013-05-02 09:18:56   A0007   HSIK3         1     22528.0
# 2013-05-02 09:19:49   A0008   HSIK3         2     22527.0
# 2013-05-02 09:22:39   A0004   HSIK3         2     22513.0
# 2013-05-02 09:22:47   A0009   HSIK3         2     22515.0
# 2013-05-02 09:23:07   A0010   HSIK3         1     22540.0
# 2013-05-02 09:24:09   A0009   HSIK3         2     22552.0
# 2013-05-02 09:24:45   A0011   HSIK3         2     22543.0
# 2013-05-02 09:25:00   A0012   HSIK3         2     22549.0
# 2013-05-02 09:26:24   A0007   HSIK3         1     22542.0
# ...

# %%
df.groupby(df.account).profit.sum()
# Out:
# account
# A0001     441.0
# A0002    4147.0
# A0003    -442.0
# A0004    1479.0
# A0005    1368.0
# A0006    1967.0
# A0007    1111.0
# A0008     -11.0
# A0009   -1790.0
# A0010   -2127.0
# A0011    -242.0
# A0012    -227.0
# A0013     692.0
# A0014    2161.0
# A0015      77.0
# A0016     -59.0
# A0017     205.0
# A0018    1019.0
# A0019    -329.0
# A0020    -153.0
# A0021     550.0
# A0022    -244.0
# A0023    1459.0
# A0024      43.0
# A0025     599.0
# A0026      11.0
# A0027     320.0
# A0028     109.0
# A0029     349.0
# A0030    -750.0
#           ...
# A1607    -185.0
# A1608    -167.0
# A1609     762.0
# A1610    1240.0
# A1611       2.0
# A1612      12.0
# A1613     136.0
# A1614     -13.0
# A1615      11.0
# A1616     -50.0
# A1617     228.0
# A1618    -156.0
# A1619    -170.0
# A1620    -183.0
# A1621    -159.0
# A1622     -57.0
# A1623      54.0
# A1624     -82.0
# A1625     -89.0
# A1626    -141.0
# A1627     -47.0
# A1628     -48.0
# A1629     -38.0
# A1630      10.0
# ...

# %%
df[df.account =='A0002']
# Out:
#                     account product  buy_sell  take_price  \
# 2013-05-02 09:15:05   A0002   HSIK3         2     22565.0
# 2013-05-02 09:38:03   A0002   HSIK3         2     22476.0
# 2013-05-02 10:18:50   A0002   HSIK3         2     22524.0
# 2013-05-02 10:20:08   A0002   HSIK3         2     22518.0
# 2013-05-03 09:16:54   A0002   HSIK3         1     22728.0
# 2013-05-03 09:17:38   A0002   HSIK3         1     22731.0
# 2013-05-03 09:32:14   A0002   HSIK3         2     22661.0
# 2013-05-03 09:52:00   A0002   HSIK3         1     22737.0
# 2013-05-03 09:55:01   A0002   HSIK3         1     22734.0
# 2013-05-03 10:32:08   A0002   HSIK3         1     22728.0
# 2013-05-03 14:11:55   A0002   HSIK3         1     22603.0
# 2013-05-06 09:16:33   A0002   HSIK3         2     22862.0
# 2013-05-06 09:33:16   A0002   HSIK3         2     22838.0
# 2013-05-06 09:47:41   A0002   HSIK3         1     22789.0
# 2013-05-06 09:54:24   A0002   HSIK3         1     22779.0
# ...

# %%
df['rate'] = 1
df
# Out:
#                     account product  buy_sell  take_price  \
# 2013-05-02 09:15:05   A0002   HSIK3         2     22565.0
# 2013-05-02 09:15:12   A0003   HSIK3         2     22560.0
# 2013-05-02 09:15:53   A0004   HSIK3         2     22554.0
# 2013-05-02 09:15:55   A0005   HSIK3         1     22553.0
# 2013-05-02 09:16:21   A0001   HSIK3         2     22524.0
# 2013-05-02 09:17:08   A0006   HSIK3         1     22535.0
# 2013-05-02 09:18:56   A0007   HSIK3         1     22528.0
# 2013-05-02 09:19:49   A0008   HSIK3         2     22527.0
# 2013-05-02 09:22:39   A0004   HSIK3         2     22513.0
# 2013-05-02 09:22:47   A0009   HSIK3         2     22515.0
# 2013-05-02 09:23:07   A0010   HSIK3         1     22540.0
# 2013-05-02 09:24:09   A0009   HSIK3         2     22552.0
# 2013-05-02 09:24:45   A0011   HSIK3         2     22543.0
# 2013-05-02 09:25:00   A0012   HSIK3         2     22549.0
# 2013-05-02 09:26:24   A0007   HSIK3         1     22542.0
# ...

# %%
df1
# Out:
#             hsi_index      rate
# date2
# 2013-05-02   22668.30       NaN
# 2013-05-03   22689.96  0.000956
# 2013-05-06   22915.09  0.009922
# 2013-05-07   23047.09  0.005760
# 2013-05-08   23244.35  0.008559
# 2013-05-09   23211.48 -0.001414
# 2013-05-10   23321.22  0.004728
# 2013-05-13   22989.81 -0.014211
# 2013-05-14   22930.28 -0.002589
# 2013-05-15   23044.24  0.004970
# 2013-05-16   23082.68  0.001668
# 2013-05-20   23493.03  0.017777
# 2013-05-21   23366.37 -0.005391
# 2013-05-22   23261.08 -0.004506
# 2013-05-23   22669.68 -0.025424
# 2013-05-24   22618.67 -0.002250
# 2013-05-27   22686.05  0.002979
# 2013-05-28   22924.25  0.010500
# 2013-05-29   22554.93 -0.016110
# 2013-05-30   22484.31 -0.003131
# 2013-05-31   22392.16 -0.004098
# 2013-06-03   22282.19 -0.004911
# 2013-06-04   22285.52  0.000149
# 2013-06-05   22069.24 -0.009705
# 2013-06-06   21838.43 -0.010458
# 2013-06-07   21575.26 -0.012051
# 2013-06-10   21615.09  0.001846
# 2013-06-11   21354.66 -0.012049
# ...

# %%
date_profit = df.groupby([df.index.date,df.account]).profit.sum()

# %%
date_profit
# Out:
#             account
# 2013-05-02  A0001      173.0
#             A0002      166.0
#             A0003       98.0
#             A0004       42.0
#             A0005      -77.0
#             A0006      130.0
#             A0007      319.0
#             A0008      141.0
#             A0009       11.0
#             A0010      202.0
#             A0011       16.0
#             A0012      170.0
#             A0013       21.0
#             A0014     -297.0
#             A0015      -21.0
#             A0016       -6.0
#             A0017       53.0
#             A0018       29.0
#             A0019      -30.0
#             A0020       -8.0
#             A0021       -3.0
#             A0022       40.0
#             A0023       95.0
#             A0024        9.0
#             A0025      -19.0
#             A0026      -42.0
#             A0027       56.0
#             A0028       29.0
#             A0029       14.0
#             A0030      -18.0
#                        ...
# ...

# %%
df2 = pd.DataFrame([date_profit])

# %%
df2 = df2.T

# %%
dateallprofit = df.groupby(df.index.date).profit.sum()

# %%
dateallprofit
# Out:
# 2013-05-02    1322.0
# 2013-05-03    1364.0
# 2013-05-06    2261.0
# 2013-05-07      81.0
# 2013-05-08     591.0
# 2013-05-09    1104.0
# 2013-05-10    -625.0
# 2013-05-13     407.0
# 2013-05-14      77.0
# 2013-05-15     210.0
# 2013-05-16    1133.0
# 2013-05-20    -558.0
# 2013-05-21      99.0
# 2013-05-22    -263.0
# 2013-05-23   -1348.0
# 2013-05-24     944.0
# 2013-05-27    1683.0
# 2013-05-28     592.0
# 2013-05-29   -1028.0
# 2013-05-30   -2136.0
# 2013-05-31    1312.0
# 2013-06-03    -401.0
# 2013-06-04     808.0
# 2013-06-05    -917.0
# 2013-06-06    -168.0
# 2013-06-07   -1228.0
# 2013-06-10     673.0
# 2013-06-11     161.0
# 2013-06-13   -1631.0
# 2013-06-14     140.0
#                ...
# 2015-11-18    2822.0
# 2015-11-19    3731.0
# 2015-11-20   -1460.0
# 2015-11-23    1911.0
# 2015-11-24    3465.0
# 2015-11-25    3492.0
# 2015-11-26     457.0
# 2015-11-27   -8260.0
# 2015-11-30    4263.0
# 2015-12-01    1363.0
# 2015-12-02    2629.0
# 2015-12-03    2626.0
# ...

# %%
sr1 = pd.DataFrame([dateallprofit])
sr1 = sr1.T
sr1
# Out:
#             profit
# 2013-05-02  1322.0
# 2013-05-03  1364.0
# 2013-05-06  2261.0
# 2013-05-07    81.0
# 2013-05-08   591.0
# 2013-05-09  1104.0
# 2013-05-10  -625.0
# 2013-05-13   407.0
# 2013-05-14    77.0
# 2013-05-15   210.0
# 2013-05-16  1133.0
# 2013-05-20  -558.0
# 2013-05-21    99.0
# 2013-05-22  -263.0
# 2013-05-23 -1348.0
# 2013-05-24   944.0
# 2013-05-27  1683.0
# 2013-05-28   592.0
# 2013-05-29 -1028.0
# 2013-05-30 -2136.0
# 2013-05-31  1312.0
# 2013-06-03  -401.0
# 2013-06-04   808.0
# 2013-06-05  -917.0
# 2013-06-06  -168.0
# 2013-06-07 -1228.0
# 2013-06-10   673.0
# 2013-06-11   161.0
# 2013-06-13 -1631.0
# 2013-06-14   140.0
# ...            ...
# 2015-11-18  2822.0
# 2015-11-19  3731.0
# 2015-11-20 -1460.0
# 2015-11-23  1911.0
# 2015-11-24  3465.0
# 2015-11-25  3492.0
# 2015-11-26   457.0
# 2015-11-27 -8260.0
# 2015-11-30  4263.0
# 2015-12-01  1363.0
# 2015-12-02  2629.0
# 2015-12-03  2626.0
# 2015-12-04  1671.0
# 2015-12-07  2259.0
# 2015-12-08  2602.0
# ...

# %%
df1['date_all_profit'] = sr1

# %%
df1
# Out:
#             hsi_index      rate  date_all_profit
# date2
# 2013-05-02   22668.30       NaN           1322.0
# 2013-05-03   22689.96  0.000956           1364.0
# 2013-05-06   22915.09  0.009922           2261.0
# 2013-05-07   23047.09  0.005760             81.0
# 2013-05-08   23244.35  0.008559            591.0
# 2013-05-09   23211.48 -0.001414           1104.0
# 2013-05-10   23321.22  0.004728           -625.0
# 2013-05-13   22989.81 -0.014211            407.0
# 2013-05-14   22930.28 -0.002589             77.0
# 2013-05-15   23044.24  0.004970            210.0
# 2013-05-16   23082.68  0.001668           1133.0
# 2013-05-20   23493.03  0.017777           -558.0
# 2013-05-21   23366.37 -0.005391             99.0
# 2013-05-22   23261.08 -0.004506           -263.0
# 2013-05-23   22669.68 -0.025424          -1348.0
# 2013-05-24   22618.67 -0.002250            944.0
# 2013-05-27   22686.05  0.002979           1683.0
# 2013-05-28   22924.25  0.010500            592.0
# ...

# %%
df2
# Out:
#                     profit
#            account
# 2013-05-02 A0001     173.0
#            A0002     166.0
#            A0003      98.0
#            A0004      42.0
#            A0005     -77.0
#            A0006     130.0
#            A0007     319.0
#            A0008     141.0
#            A0009      11.0
#            A0010     202.0
#            A0011      16.0
#            A0012     170.0
#            A0013      21.0
#            A0014    -297.0
#            A0015     -21.0
#            A0016      -6.0
#            A0017      53.0
#            A0018      29.0
#            A0019     -30.0
#            A0020      -8.0
#            A0021      -3.0
#            A0022      40.0
#            A0023      95.0
#            A0024       9.0
#            A0025     -19.0
#            A0026     -42.0
#            A0027      56.0
#            A0028      29.0
#            A0029      14.0
#            A0030     -18.0
# ...                    ...
# 2015-12-30 A1576     -12.0
# ...

# %%
df1.to_hdf('hsi_with_allprofit.h5','hsi')

# %%
df3 = df2.unstack()

# %%
df3
# Out:
#            profit                                                         \
# account     A0001  A0002  A0003  A0004  A0005  A0006  A0007  A0008 A0009
# 2013-05-02  173.0  166.0   98.0   42.0  -77.0  130.0  319.0  141.0  11.0
# 2013-05-03  323.0  -38.0   75.0   86.0  104.0   35.0  -80.0 -135.0  20.0
# 2013-05-06  478.0   95.0   51.0   21.0    NaN   99.0  -43.0    NaN   NaN
# 2013-05-07 -223.0  -16.0  -46.0    NaN    NaN  102.0    NaN    NaN -55.0
# 2013-05-08  -57.0  -28.0  -34.0   10.0    NaN  185.0  117.0  -17.0   NaN
# 2013-05-09  -43.0   97.0  -54.0   45.0    NaN  156.0  -64.0    NaN  -3.0
# 2013-05-10   23.0 -111.0 -116.0  -40.0    NaN   29.0   44.0    NaN   5.0
# 2013-05-13  122.0   82.0  143.0  -30.0    NaN   42.0  253.0    NaN  24.0
# 2013-05-14 -245.0  -58.0  -87.0   85.0    NaN   48.0 -242.0    NaN -18.0
# 2013-05-15    NaN  108.0    NaN   23.0    NaN  -76.0  -31.0    NaN -47.0
# 2013-05-16    NaN   49.0    NaN   47.0    NaN    NaN  340.0    NaN   NaN
# ...

# %%
df3.index = pd.to_datetime(df3.index)

# %%
df3.index
# Out:
# DatetimeIndex(['2013-05-02', '2013-05-03', '2013-05-06', '2013-05-07',
#                '2013-05-08', '2013-05-09', '2013-05-10', '2013-05-13',
#                '2013-05-14', '2013-05-15',
#                ...
#                '2015-12-16', '2015-12-17', '2015-12-18', '2015-12-21',
#                '2015-12-22', '2015-12-23', '2015-12-24', '2015-12-28',
#                '2015-12-29', '2015-12-30'],
#               dtype='datetime64[ns]', length=658, freq=None)

# %%
df3.to_hdf('all_account_profit.h5','hsi')
