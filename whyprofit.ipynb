#            2017-07-19           A1709  10114836   22:35:00          0
#            2017-07-19           A1709  10114837   22:35:00          0
# ...

# %%
sr1 = df1.groupby(df1.instrument).realized_pl.sum()
sr1
# Out:
# instrument
# A1709      -500.0
# A1801     -2270.0
# AL1710     -325.0
# BU1709     -780.0
# BU1712    -1180.0
# BU1801      820.0
# C1709       -20.0
# C1801     -2700.0
# CF801     13000.0
# CS1709     5000.0
# CS1801     7310.0
# CU1710    -1600.0
# CU1711     -700.0
# FG709      -740.0
# FG801     -2720.0
# HC1801     -250.0
# I1801     11100.0
# JD1709    -5080.0
# JD1801     2090.0
# JM1801    -3000.0
# L1709     -1150.0
# L1801     -2750.0
# M1709     -1480.0
# M1801     -5720.0
# MA709     -2800.0
# MA801      7760.0
# NI1801    12160.0
# OI801     10260.0
# P1709      1820.0
# P1801     12460.0
# PP1709       35.0
# PP1801     6760.0
# RB1710     5880.0
# RB1801    18910.0
# RM709     -1920.0
# RM801     -1060.0
# RU1709     2200.0
# RU1801     4250.0
# SM709    -15570.0
# SM801     -6840.0
# SR801      -540.0
# TA709     -2780.0
# TA801     10800.0
# V1709      3700.0
# V1801     18675.0
# Y1801      4660.0
# ZN1709    -1650.0
# ZN1710     8525.0
# ZN1712    -3650.0
# ...

# %%
sr1.sort_values(ascending=False)
# Out:
# instrument
# RB1801    18910.0
# V1801     18675.0
# CF801     13000.0
# P1801     12460.0
# NI1801    12160.0
# I1801     11100.0
# TA801     10800.0
# OI801     10260.0
# ZN1710     8525.0
# MA801      7760.0
# CS1801     7310.0
# PP1801     6760.0
# RB1710     5880.0
# CS1709     5000.0
# Y1801      4660.0
# RU1801     4250.0
# V1709      3700.0
# RU1709     2200.0
# JD1801     2090.0
# P1709      1820.0
# BU1801      820.0
# PP1709       35.0
# C1709       -20.0
# HC1801     -250.0
# AL1710     -325.0
# A1709      -500.0
# SR801      -540.0
# CU1711     -700.0
# FG709      -740.0
# BU1709     -780.0
# RM801     -1060.0
# L1709     -1150.0
# BU1712    -1180.0
# M1709     -1480.0
# CU1710    -1600.0
# ZN1709    -1650.0
# RM709     -1920.0
# A1801     -2270.0
# C1801     -2700.0
# FG801     -2720.0
# L1801     -2750.0
# TA709     -2780.0
# MA709     -2800.0
# JM1801    -3000.0
# ZN1712    -3650.0
# JD1709    -5080.0
# M1801     -5720.0
# SM801     -6840.0
# SM709    -15570.0
# ...

# %%
df2 = pd.DataFrame([sr1])
df2 =df2.T
df2
# Out:
#             realized_pl
# instrument
# A1709            -500.0
# A1801           -2270.0
# AL1710           -325.0
# BU1709           -780.0
# BU1712          -1180.0
# BU1801            820.0
# C1709             -20.0
# C1801           -2700.0
# CF801           13000.0
# CS1709           5000.0
# CS1801           7310.0
# CU1710          -1600.0
# CU1711           -700.0
# FG709            -740.0
# FG801           -2720.0
# HC1801           -250.0
# I1801           11100.0
# JD1709          -5080.0
# JD1801           2090.0
# JM1801          -3000.0
# L1709           -1150.0
# L1801           -2750.0
# M1709           -1480.0
# M1801           -5720.0
# MA709           -2800.0
# MA801            7760.0
# NI1801          12160.0
# OI801           10260.0
# P1709            1820.0
# P1801           12460.0
# PP1709             35.0
# PP1801           6760.0
# RB1710           5880.0
# RB1801          18910.0
# RM709           -1920.0
# RM801           -1060.0
# ...

# %%
df2.to_excel('123.xlsx')

# %%
df3 = pd.read_excel('C:/Users/Administrator/Desktop/Work/data/CTAtrade_account/001810115002/123.xlsx')
df3
# Out:
#    instrument  realized_pl  Unnamed: 2 Unnamed: 3
# 0       A1709         -500        1709          A
# 1       A1801        -2270        1801          A
# 2      AL1710         -325        1710         AL
# 3      BU1709         -780        1709         BU
# 4      BU1712        -1180        1712         BU
# 5      BU1801          820        1801         BU
# 6       C1709          -20        1709          C
# 7       C1801        -2700        1801          C
# 8       CF801        13000         801         CF
# 9      CS1709         5000        1709         CS
# 10     CS1801         7310        1801         CS
# 11     CU1710        -1600        1710         CU
# 12     CU1711         -700        1711         CU
# 13      FG709         -740         709         FG
# 14      FG801        -2720         801         FG
# 15     HC1801         -250        1801         HC
# 16      I1801        11100        1801          I
# 17     JD1709        -5080        1709         JD
# ...

# %%
df3.drop('instrument', axis=1,inplace=True)

# %%
df3
# Out:
#     realized_pl  Unnamed: 2 Unnamed: 3
# 0          -500        1709          A
# 1         -2270        1801          A
# 2          -325        1710         AL
# 3          -780        1709         BU
# 4         -1180        1712         BU
# 5           820        1801         BU
# 6           -20        1709          C
# 7         -2700        1801          C
# 8         13000         801         CF
# 9          5000        1709         CS
# 10         7310        1801         CS
# 11        -1600        1710         CU
# 12         -700        1711         CU
# 13         -740         709         FG
# 14        -2720         801         FG
# 15         -250        1801         HC
# 16        11100        1801          I
# 17        -5080        1709         JD
# 18         2090        1801         JD
# 19        -3000        1801         JM
# 20        -1150        1709          L
# 21        -2750        1801          L
# 22        -1480        1709          M
# ...

# %%
df3.columns = ['realized_pl','abcd','instrument']

# %%
df3.drop('abcd', axis=1,inplace=True)

# %%
df3.index = df3.instrument

# %%
df3.drop('instrument', axis=1,inplace=True)

# %%
df3
# Out:
#             realized_pl
# instrument
# A                  -500
# A                 -2270
# AL                 -325
# BU                 -780
# BU                -1180
# BU                  820
# C                   -20
# C                 -2700
# CF                13000
# CS                 5000
# CS                 7310
# CU                -1600
# CU                 -700
# FG                 -740
# FG                -2720
# HC                 -250
# I                 11100
# JD                -5080
# JD                 2090
# JM                -3000
# L                 -1150
# L                 -2750
# M                 -1480
# M                 -5720
# MA                -2800
# MA                 7760
# NI                12160
# OI                10260
# P                  1820
# P                 12460
# PP                   35
# PP                 6760
# RB                 5880
# RB                18910
# RM                -1920
# RM                -1060
# ...

# %%
sr3 = df3.groupby(df3.index).realized_pl.sum()

# %%
sr3
# Out:
# instrument
# A     -2770
# AL     -325
# BU    -1140
# C     -2720
# CF    13000
# CS    12310
# CU    -2300
# FG    -3460
# HC     -250
# I     11100
# JD    -2990
# JM    -3000
# L     -3900
# M     -7200
# MA     4960
# NI    12160
# OI    10260
# P     14280
# PP     6795
# RB    24790
# RM    -2980
# RU     6450
# SM   -22410
# SR     -540
# TA     8020
# V     22375
# Y      4660
# ZN     3225
# Name: realized_pl, dtype: int64

# %%
# %matplotlib inline

# %%
sr3.sort_values(ascending=False)
# Out:
# instrument
# RB    24790
# V     22375
# P     14280
# CF    13000
# CS    12310
# NI    12160
# I     11100
# OI    10260
# TA     8020
# PP     6795
# RU     6450
# MA     4960
# Y      4660
# ZN     3225
# HC     -250
# AL     -325
# SR     -540
# BU    -1140
# CU    -2300
# C     -2720
# A     -2770
# RM    -2980
# JD    -2990
# JM    -3000
# FG    -3460
# L     -3900
# M     -7200
# SM   -22410
# Name: realized_pl, dtype: int64

# %%
sr4 = sr3[sr3>0]

# %%
sr4 =sr4.sort_values(ascending=False)

# %%
sr4.plot(kind='pie', subplots=True,autopct='%.2f',figsize=(8, 8) )
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000000B5293C8>], dtype=object)

# %%
df4 = df[df.instrument == ('RB1801' )]
df4
# Out:
#                 instrument  order_no trade_time  direction  order_price  lots  \
# real_trade_date
# 2017-07-27          RB1801  01885515   14:20:08          0       3432.0     1
# 2017-07-27          RB1801  01887895   14:20:32          0       3430.0     1
# 2017-07-27          RB1801  01889941   14:21:03          0       3430.0     1
# 2017-07-27          RB1801  01896654   14:22:19          0       3429.0     1
# 2017-07-27          RB1801  02093401   14:59:21          0       3444.0     1
# 2017-07-28          RB1801  00889242   09:00:30          1       3470.0     2
# 2017-07-28          RB1801  00184163   21:21:02          1       3436.0     2
# 2017-07-28          RB1801  00205198   21:25:02          0       3441.0     2
# 2017-07-28          RB1801  00259219   21:34:58          1       3439.0     2
# 2017-07-28          RB1801  00259223   21:34:58          1       3439.0     1
# 2017-07-28          RB1801  00259224   21:34:58          1       3439.0     2
# ...

# %%
df4.trade_time
# Out:
# real_trade_date
# 2017-07-27    14:20:08
# 2017-07-27    14:20:32
# 2017-07-27    14:21:03
# 2017-07-27    14:22:19
# 2017-07-27    14:59:21
# 2017-07-28    09:00:30
# 2017-07-28    21:21:02
# 2017-07-28    21:25:02
# 2017-07-28    21:34:58
# 2017-07-28    21:34:58
# 2017-07-28    21:34:58
# 2017-07-28    21:36:22
# 2017-07-28    21:36:22
# 2017-07-28    21:47:45
# 2017-07-28    22:48:14
# 2017-07-31    21:08:08
# 2017-07-31    21:08:08
# 2017-07-31    21:11:26
# 2017-07-31    22:19:37
# 2017-08-11    09:11:24
# 2017-08-11    09:17:45
# 2017-08-11    09:35:17
# 2017-08-11    09:40:42
# 2017-08-11    09:41:54
# 2017-08-11    21:00:52
# 2017-08-11    21:00:52
# 2017-08-11    21:02:53
# 2017-08-11    21:04:26
# 2017-08-11    21:08:02
# 2017-08-11    21:11:38
#                 ...
# 2017-09-22    14:19:17
# 2017-09-22    14:23:12
# 2017-09-22    14:23:12
# 2017-09-22    14:33:38
# 2017-09-22    14:39:47
# 2017-09-28    21:19:19
# 2017-09-29    09:02:55
# 2017-09-29    09:03:15
# ...

# %%
df5 = df[df.instrument == ('RB1710' )]

# %%
df5
# Out:
#                 instrument  order_no trade_time  direction  order_price  lots  \
# real_trade_date
# 2017-07
# 2017-07-27 09:33:56     RB1710  00958583   09:33:56          1       3576.0
# 2017-07-27 09:43:36     RB1710  01023873   09:43:36          0       3577.0
# 2017-07-27 14:16:44     RB1710  01864067   14:16:44          0       3558.0
# 2017-07-27 14:17:00     RB1710  01866131   14:17:00          0       3560.0
# 2017-07-27 14:17:08     RB1710  01867286   14:17:08          0       3557.0
# ...

# %%
df8.groupby(df8.index.hour).realized_pl.sum()
# Out:
# trade_datetime
# 9     -9810.0
# 10    -4110.0
# 11     -400.0
# 13    -1730.0
# 14   -10480.0
# 21   -10870.0
# 22    -5260.0
# Name: realized_pl, dtype: float64

# %%
sr5 = df6.groupby(df6.index.date).realized_pl.sum()
sr5
# Out:
# 2017-07-20    -230.0
# 2017-07-24     730.0
# 2017-07-25   -1480.0
# 2017-07-27    -180.0
# 2017-07-28    1580.0
# 2017-07-31    5760.0
# 2017-08-02    1330.0
# 2017-08-03     400.0
# 2017-08-11   -1220.0
# 2017-08-14    1050.0
# 2017-08-15    -180.0
# 2017-08-25   -1030.0
# 2017-08-30   -2500.0
# 2017-08-31      90.0
# 2017-09-01    -210.0
# 2017-09-11   -1470.0
# 2017-09-12     660.0
# 2017-09-13    1000.0
# 2017-09-14   -1320.0
# 2017-09-18    9390.0
# 2017-09-19   -1170.0
# 2017-09-20    6410.0
# 2017-09-22    -770.0
# 2017-09-29    2720.0
# 2017-10-13    5310.0
# 2017-10-16     120.0
# Name: realized_pl, dtype: float64

# %%
sr5.plot()

# %%
df9 = df[df.instrument == ('V1709' )]
df9
# Out:
#                 instrument  order_no trade_time  direction  order_price  lots  \
# real_trade_date
# 2017-07-18           V1709  30324499   10:00:30          0       6540.0     3
# 2017-07-18           V1709  30327219   10:01:43          0       6540.0     2
# 2017-07-18           V1709  30330267   10:03:06          0       6535.0     1
# 2017-07-18           V1709  30344493   10:14:19          0       6540.0     1
# 2017-07-18           V1709  30497270   13:41:16          1       6640.0     2
# 2017-07-18           V1709  30498320   13:41:43          1       6640.0     2
# 2017-07-18           V1709  30498933   13:42:08          1       6645.0     2
# 2017-07-18           V1709  30506595   13:46:23          1       6665.0     1
#
#                  turnover  open_close   fee  realized_pl real_trade_date
# real_trade_date
# 2017-07-18        98100.0           0  3.06          0.0      2017-07-18
# 2017-07-18        65400.0           0  2.04          0.0      2017-07-18
# ...

# %%
df10 = df[df.instrument == ('V1801' )]
df10
# Out:
#                 instrument  order_no trade_time  direction  order_price  lots  \
# real_trade_date
# 2017-08-18           V1801  30217337   09:03:24          0       7155.0     2
# 2017-08-18           V1801  30403080   10:41:42          1       7360.0     1
# 2017-08-18           V1801  30403174   10:41:44          1       7360.0     1
# 2017-08-24           V1801  30312826   09:00:14          0       7350.0     1
# 2017-08-24           V1801  30313505   09:00:18          0       7350.0     1
# 2017-08-24           V1801  30338982   09:04:25          0       7415.0     1
# 2017-08-24           V1801  30342245   09:05:03          0       7400.0     1
# 2017-08-24           V1801  30355948   09:08:40          1       7395.0     1
# 2017-08-24           V1801  30363657   09:11:03          1       7380.0     1
# 2017-08-24           V1801  30369925   09:12:30          1       7370.0     1
# 2017-08-24           V1801  30372429   09:13:06          1       7375.0     1
# ...

# %%
df10 = pd.concat([df9,df10])
df10
# Out:
#                 instrument  order_no trade_time  direction  order_price  lots  \
# real_trade_date
# 2017-07
# Out:
#                     instrument  order_no trade_time  direction  order_price  \
# trade_datetime
# 2017-07-18 13:41:16      V1709  30497270   13:41:16          1       6640.0
# 2017-07-18 13:41:43      V1709  30498320   13:41:43          1       6640.0
# 2017-07-18 13:42:08      V1709  30498933   13:42:08          1       6645.0
# 2017-07-18 13:46:23      V1709  30506595   13:46:23          1       6665.0
# 2017-08-18 10:41:42      V1801  30403080   10:41:42          1       7360.0
# 2017-08-18 10:41:44      V1801  30403174   10:41:44          1       7360.0
# 2017-08-24 09:08:40      V1801  30355948   09:08:40          1       7395.0
# 2017-08-24 09:11:03      V1801  30363657   09:11:03          1       7380.0
# 2017-08-24 09:12:30      V1801  30369925   09:12:30          1       7370.0
# 2017-08-24 09:13:06      V1801  30372429   09:13:06          1       7375.0
# 2017-08-25 09:42:45      V1801  30486954   09:42:45          1       7420.0
# ...

# %%
df11.sort_index()
# Out:
#                     instrument  order_no trade_time  direction  order_price  \
# trade_datetime
# 2017-07-18 13:41:16      V1709  30497270   13:41:16          1       6640.0
# 2017-07-18 13:41:43      V1709  30498320   13:41:43          1       6640.0
# 2017-07-18 13:42:08      V1709  30498933   13:42:08          1       6645.0
# 2017-07-18 13:46:23      V1709  30506595   13:46:23          1       6665.0
# 2017-08-18 10:41:42      V1801  30403080   10:41:42          1       7360.0
# 2017-08-18 10:41:44      V1801  30403174   10:41:44          1       7360.0
# 2017-08-24 09:08:40      V1801  30355948   09:08:40          1       7395.0
# 2017-08-24 09:11:03      V1801  30363657   09:11:03          1       7380.0
# 2017-08-24 09:12:30      V1801  30369925   09:12:30          1       7370.0
# 2017-08-24 09:13:06      V1801  30372429   09:13:06          1       7375.0
# 2017-08-25 09:42:45      V1801  30486954   09:42:45          1       7420.0
# ...

# %%
df11.count()
# Out:
# instrument         38
# order_no           38
# trade_time         38
# direction          38
# order_price        38
# lots               38
# turnover           38
# open_close         38
# fee                38
# realized_pl        38
# real_trade_date    38
# trade_datetime     38
# dtype: int64

# %%
df11[df11.realized_pl <  0].realized_pl.sum()
# Out:
# -1125.0

# %%
df11.index = pd.to_datetime(df11.index)

# %%
df11.groupby(df11.index.hour).count()
# Out:
#                 instrument  order_no  trade_time  direction  order_price  \
# trade_datetime
# 9                       17        17          17         17           17
# 10                       2         2           2          2            2
# 13                       6         6           6          6            6
# 14                      13        13          13         13           13
#
#                 lots  turnover  open_close  fee  realized_pl  real_trade_date  \
# trade_datetime
# 9                 17        17          17   17           17               17
# 10                 2         2           2    2            2                2
# 13                 6         6           6    6            6                6
# 14                13        13          13   13           13               13
#
#                 trade_datetime
# trade_datetime
# 9                           17
# 10                           2
# 13                           6
# ...

# %%
df11.groupby(df11.index.hour).lots.sum()
# Out:
# trade_datetime
# 9     20
# 10     2
# 13     9
# 14    16
# Name: lots, dtype: int32

# %%
df12 = df11[df11.realized_pl > 0]
df12
# Out:
#                     instrument  order_no trade_time  direction  order_price  \
# trade_datetime
# 2017-07-18 13:41:16      V1709  30497270   13:41:16          1       6640.0
# 2017-07-18 13:41:43      V1709  30498320   13:41:43          1       6640.0
# 2017-07-18 13:42:08      V1709  30498933   13:42:08          1       6645.0
# 2017-07-18 13:46:23      V1709  30506595   13:46:23          1       6665.0
# 2017-08-18 10:41:42      V1801  30403080   10:41:42          1       7360.0
# 2017-08-18 10:41:44      V1801  30403174   10:41:44          1       7360.0
# 2017-08-24 09:08:40      V1801  30355948   09:08:40          1       7395.0
# 2017-08-24 09:11:03      V1801  30363657   09:11:03          1       7380.0
# 2017-08-30 14:14:56      V1801  30662386   14:14:56          1       7500.0
# 2017-08-30 14:15:31      V1801  30663130   14:15:31          1       7505.0
# 2017-08-30 14:40:45      V1801  30712608   14:40:45          1       7495.0
# ...

# %%
df12.index = pd.to_datetime(df12.index)

# %%
df12.groupby(df12.index.hour).realized_pl.sum()
# Out:
# trade_datetime
# 9     7750.0
# 10    2050.0
# 13    4925.0
# 14    8775.0
# Name: realized_pl, dtype: float64

# %%
df12.groupby(df12.index.hour).count()
# Out:
#                 instrument  order_no  trade_time  direction  order_price  \
# trade_datetime
# 9                       11        11          11         11           11
# 10                       2         2           2          2            2
# 13                       5         5           5          5            5
# 14                       9         9           9          9            9
#
#                 lots  turnover  open_close  fee  realized_pl  real_trade_date  \
# trade_datetime
# 9                 11        11          11   11           11               11
# 10                 2         2           2    2            2                2
# 13                 5         5           5    5            5                5
# 14                 9         9           9    9            9                9
#
#                 trade_datetime
# trade_datetime
# 9                           11
# 10                           2
# 13                           5
# ...

# %%
df13 = df11[df11.realized_pl < 0]

# %%
df13.groupby(df13.index.hour).count()
# Out:
#                 instrument  order_no  trade_time  direction  order_price  \
# trade_datetime
# 9                        6         6           6          6            6
# 13                       1         1           1          1            1
# 14                       3         3           3          3            3
#
#                 lots  turnover  open_close  fee  realized_pl  real_trade_date  \
# trade_datetime
# 9                  6         6           6    6            6                6
# 13                 1         1           1    1            1                1
# 14                 3         3           3    3            3                3
#
#                 trade_datetime
# trade_datetime
# 9                            6
# 13                           1
# 14                           3

# %%
df13.groupby(df13.index.hour).realized_pl.sum()
# Out:
# trade_datetime
# 9    -750.0
# 13    -75.0
# 14   -300.0
# Name: realized_pl, dtype: float64

# %%
df14 = df[df.instrument == ('P1709' )]
df15 = df[df.instrument == ('P1801' )]
df15 = pd.concat([df14,df15])
df15['trade_datetime'] = df15.real_trade_date + ' ' + df15.trade_time
df15.index = df15.trade_datetime
df15.index = pd.to_datetime(df15.index)
df15 = df15.sort_index()
df15
# Out:
#                     instrument  order_no trade_time  direction  order_price  \
# trade_datetime
# 2017-07-18 09:14:04      P1709  10182599   09:14:04          1       5436.0
# 2017-07-18 09:22:18      P1709  10210752   09:22:18          1       5438.0
# 2017-07-18 09:35:49      P1709  10231061   09:35:49          0       5442.0
# 2017-07-18 09:44:36      P1709  10241155   09:44:36          0       5442.0
# 2017-07-18 09:47:21      P1709  10244528   09:47:21          0       5448.0
# 2017-07-18 13:30:03      P1709  10368437   13:30:03          1       5404.0
# 2017-07-18 13:31:15      P1709  10371003   13:31:15          1       5406.0
# 2017-07-18 13:31:28      P1709  10371449   13:31:28          1       5408.0
# 2017-07-18 13:51:43      P1709  10445485   13:51:43          0       5352.0
# 2017-07-18 13:51:43      P1709  10445692   13:51:43          0       5352.0
# 2017-07-18 13:51:44      P1709  10445726   13:51:44          0       5352.0
# ...

# %%
df16 = df15[df15.open_close == 1]
df16
# Out:
#                     instrument  order_no trade_time  direction  order_price  \
# trade_datetime
# 2017-07-18 09:35:49      P1709  10231061   09:35:49          0       5442.0
# 2017-07-18 09:44:36      P1709  10241155   09:44:36          0       5442.0
# 2017-07-18 09:47:21      P1709  10244528   09:47:21          0       5448.0
# 2017-07-18 13:51:43      P1709  10445485   13:51:43          0       5352.0
# 2017-07-18 13:51:43      P1709  10445692   13:51:43          0       5352.0
# 2017-07-18 13:51:44      P1709  10445726   13:51:44          0       5352.0
# 2017-07-18 13:52:16      P1709  10447807   13:52:16          0       5350.0
# 2017-07-20 23:20:49      P1801  10153209   23:20:49          1       5260.0
# 2017-07-21 10:36:00      P1801  10387049   10:36:00          1       5294.0
# 2017-07-21 10:48:48      P1801  10420129   10:48:48          1       5292.0
# 2017-07-21 10:48:48      P1801  10420130   10:48:48          1       5292.0
# ...

# %%
df16.count()
# Out:
# instrument         177
# order_no           177
# trade_time         177
# direction          177
# order_price        177
# lots               177
# turnover           177
# open_close         177
# fee                177
# realized_pl        177
# real_trade_date    177
# trade_datetime     177
# dtype: int64

# %%
df17 = df16[df16.realized_pl > 0]
df17.count()
# Out:
# instrument         56
# order_no           56
# trade_time         56
# direction          56
# order_price        56
# lots               56
# turnover           56
# open_close         56
# fee                56
# realized_pl        56
# real_trade_date    56
# trade_datetime     56
# dtype: int64

# %%
df17.realized_pl.sum()
# Out:
# 31500.0

# %%
df18 = df16[df16.realized_pl < 0]
df18.realized_pl.sum()
# Out:
# -17220.0

# %%
df18.groupby(df18.index.hour).realized_pl.sum()
# Out:
# trade_datetime
# 9    -3180.0
# 10   -1400.0
# 11   -1460.0
# 13   -3640.0
# 14   -1340.0
# 20     -80.0
# 21   -2840.0
# 22   -2340.0
# 23    -940.0
# Name: realized_pl, dtype: float64

# %%
df17.groupby(df17.index.hour).realized_pl.sum()
# Out:
# trade_datetime
# 9     13020.0
# 10     6480.0
# 11      520.0
# 13     2160.0
# 14      460.0
# 21     5500.0
# 22     1680.0
# 23     1680.0
# Name: realized_pl, dtype: float64

# %%
df17.groupby(df17.index.hour).count()
# Out:
#                 instrument  order_no  trade_time  direction  order_price  \
# trade_datetime
# 9                       11        11          11         11           11
# 10                      14        14          14         14           14
# 11                       1         1           1          1            1
# 13                       4         4           4          4            4
# 14                       2         2           2          2            2
# 21                      16        16          16         16           16
# 22                       5         5           5          5            5
# 23                       3         3           3          3            3
#
#                 lots  turnover  open_close  fee  realized_pl  real_trade_date  \
# trade_datetime
# 9                 11        11          11   11           11               11
# 10                14        14          14   14           14               14
# ...

# %%
df16.groupby(df16.index.hour).count()
# Out:
#                 instrument  order_no  trade_time  direction  order_price  \
# trade_datetime
# 9                       32        32          32         32           32
# 10                      26        26          26         26           26
# 11                      13        13          13         13           13
# 13                      17        17          17         17           17
# 14                      15        15          15         15           15
# 20                       1         1           1          1            1
# 21                      33        33          33         33           33
# 22                      27        27          27         27           27
# 23                      13        13          13         13           13
#
#                 lots  turnover  open_close  fee  realized_pl  real_trade_date  \
# trade_datetime
# 9                 32        32          32   32           32               32
# ...

# %%
df16.groupby(df16.index.hour).lots.sum()
# Out:
# trade_datetime
# 9     52
# 10    31
# 11    22
# 13    26
# 14    20
# 20     1
# 21    48
# 22    31
# 23    21
# Name: lots, dtype: int32

# %%
df15.groupby([df15.index.date,df15.open_close]).lots.sum()
# Out:
#             open_close
# 2017-07-18  0              8
#             1              8
# 2017-07-20  0              4
#             1              1
# 2017-07-21  0             10
#             1              8
# 2017-07-24  0              1
#             1              6
# 2017-07-25  0              3
# 2017-07-26  0              2
#             1              5
# 2017-08-08  0              4
#             1              2
# 2017-08-10  0              8
#             1              6
# 2017-08-11  0              3
#             1              7
# 2017-08-14  0              7
#             1              7
# 2017-08-15  0             14
#             1             10
# 2017-08-16  1              2
# 2017-08-17  1              2
# 2017-08-18  0              2
#             1              2
# 2017-08-29  0             15
#             1              6
# 2017-08-30  1              9
# 2017-09-01  0              7
#             1              7
# 2017-09-04  0             19
# ...

# %%
df19 = df[df.instrument == ('CF801' )]
df19['trade_datetime'] = df19.real_trade_date + ' ' + df19.trade_time
df19.index = df19.trade_datetime
df19.index = pd.to_datetime(df19.index)
df19 = df19.sort_index()
df19
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                     instrument  order_no trade_time  direction  order_price  \
# trade_datetime
# 2017-08-04 09:03:01      CF801  00646178   09:03:01          0      15070.0
# 2017-08-04 11:04:00      CF801  01281933   11:04:00          0      15040.0
# 2017-08-07 09:09:40      CF801  00957283   09:09:40          1      15060.0
# 2017-08-07 09:10:40      CF801  01052463   09:10:40          1      14950.0
# 2017-08-07 11:27:02      CF801  01854436   11:27:02          0      15095.0
# 2017-08-07 13:38:02      CF801  01900223   13:38:02          0      15085.0
# 2017-08-08 09:40:05      CF801  00872778   09:40:05          1      15100.0
# ...

# %%
df20 = df19[df19.open_close == 1]

# %%
print ("Total_trade is ", df20.realized_pl.count())
# Out:
# Total_trade is  90

# %%
df21 = df20[df20.realized_pl > 0 ]

# %%
print ("win_trade is ", df21.realized_pl.count())
# Out:
# win_trade is  27

# %%
print ("profit is ", df21.realized_pl.sum())
# Out:
# profit is  26825.0

# %%
df22 = df20[df20.realized_pl < 0]
print ("loss is ", df22.realized_pl.sum())
# Out:
# loss is  -13825.0

# %%
print ("trade_count ", df20.groupby(df20.index.hour).realized_pl.count())
print ("trade_lots ", df20.groupby(df20.index.hour).lots.sum())
# Out:
# trade_count  trade_datetime
# 9     20
# 10     4
# 11    16
# 13    16
# 14    12
# 21    15
# 22     3
# 23     4
# Name: realized_pl, dtype: int64
# trade_lots  trade_datetime
# 9     20
# 10     4
# 11    16
# 13    16
# 14    12
# 21    16
# 22     3
# 23     4
# Name: lots, dtype: int32

# %%
print ("win_profit ", df21.groupby(df21.index.hour).realized_pl.sum())
print ("win_count ", df21.groupby(df21.index.hour).realized_pl.count())
# Out:
# win_profit  trade_datetime
# 9     4725.0
# 10    2400.0
# 11    2900.0
# 13    8150.0
# 14    1250.0
# 21    7400.0
# Name: realized_pl, dtype: float64
# win_count  trade_datetime
# 9     5
# 10    3
# 11    8
# 13    4
# 14    3
# 21    4
# Name: realized_pl, dtype: int64

# %%
print ("loss_profit ", df22.groupby(df22.index.hour).realized_pl.sum())
print ("loss_count ", df22.groupby(df22.index.hour).realized_pl.count())
# Out:
# loss_profit  trade_datetime
# 9    -5875.0
# 10     -25.0
# 11    -675.0
# 13   -2425.0
# 14   -1375.0
# 21   -2550.0
# 22    -125.0
# 23    -775.0
# Name: realized_pl, dtype: float64
# loss_count  trade_datetime
# 9     15
# 10     1
# 11     7
# 13    12
# 14     9
# 21    11
# 22     2
# 23     4
# Name: realized_pl, dtype: int64

# %%
df19.groupby([df19.index.date,df19.open_close]).lots.sum()
# Out:
#             open_close
# 2017-08-04  0              2
# 2017-08-07  0              2
#             1              2
# 2017-08-08  0              2
#             1              2
# 2017-08-09  0              2
#             1              2
# 2017-08-10  0              1
#             1              3
# 2017-08-28  0             10
#             1              7
# 2017-08-29  0              2
#             1              5
# 2017-09-01  0              7
#             1              4
# 2017-09-04  0              3
# 2017-09-05  1              3
# 2017-09-06  0              2
# 2017-09-07  1              5
# 2017-09-08  0              3
#             1              3
# 2017-09-12  0             24
#             1             22
# 2017-09-13  0              5
#             1              7
# 2017-09-21  0              2
# 2017-09-22  0              6
#             1              4
# 2017-09-25  0             10
#             1             13
# 2017-09-26  0              1
# ...

# %%
df23 = df[df.instrument == ('CS1709' )]
df24 = df[df.instrument == ('CS1801' )]

df25 = pd.concat([df23,df24])
df25['trade_datetime'] = df25.real_trade_date + ' ' + df25.trade_time
df25.index = df25.trade_datetime
df25.index = pd.to_datetime(df25.index)
df25 = df25.sort_index()

df26 = df25[df25.open_close == 1]
print ("Total_trade is ", df26.realized_pl.count())
print ("trade_count ", df26.groupby(df26.index.hour).realized_pl.count())
print ("trade_lots ", df26.groupby(df26.index.hour).lots.sum())

df27 = df26[df26.realized_pl > 0 ]
print ("win_trade is ", df27.realized_pl.count())
print ("profit is ", df27.realized_pl.sum())
print ("win_profit ", df27.groupby(df27.index.hour).realized_pl.sum())
print ("win_count ", df27.groupby(df27.index.hour).realized_pl.count())

df28 = df26[df26.realized_pl < 0]
print ("loss is ", df28.realized_pl.sum())
print ("loss_profit ", df28.groupby(df28.index.hour).realized_pl.sum())
print ("loss_count ", df28.groupby(df28.index.hour).realized_pl.count())
# Out:
# Total_trade is  215
# trade_count  trade_datetime
# 8      5
# 9     97
# 10    25
# 11    19
# 13    18
# 14    51
# Name: realized_pl, dtype: int64
# trade_lots  trade_datetime
# 8      15
# 9     333
# 10     96
# 11     90
# 13     49
# 14    164
# Name: lots, dtype: int32
# win_trade is  60
# profit is  34250.0
# win_profit  trade_datetime
# 8      1410.0
# 9      6230.0
# 10     6010.0
# 11     3600.0
# 13     1790.0
# 14    15210.0
# Name: realized_pl, dtype: float64
# win_count  trade_datetime
# 8      1
# 9     13
# 10    14
# 11     9
# 13     4
# 14    19
# Name: realized_pl, dtype: int64
# loss is  -21940.0
# loss_profit  trade_datetime
# 8      -150.0
# 9    -13920.0
# 10    -1970.0
# 11    -2020.0
# 13     -930.0
# 14    -2950.0
# Name: realized_pl, dtype: float64
# loss_count  trade_datetime
# 8      4
# 9     84
# 10    11
# 11     9
# 13    14
# 14    27
# Name: realized_pl, dtype: int64

# %%
df25.groupby([df25.index.date,df25.open_close]).lots.sum()
# Out:
#             open_close
# 2017-07-18  0              20
# 2017-07-19  0              15
#             1              25
# 2017-07-20  0              37
#             1              35
# 2017-07-21  0              78
#             1              90
# 2017-08-02  0              12
#             1               5
# 2017-08-03  0              10
#             1               2
# 2017-08-04  0              25
#             1              30
# 2017-08-07  0             110
#             1              85
# 2017-08-08  0               5
#             1              40
# 2017-08-09  0               5
# 2017-08-10  0               2
# 2017-08-11  0              20
#             1              13
# 2017-08-14  1              13
# 2017-08-16  0               4
#             1               4
# 2017-08-17  0              41
#             1              24
# 2017-08-18  0               2
#             1              20
# 2017-08-21  0              32
#             1              27
# ...

# %%
#df23 = df[df.instrument == ('CS1709' )]
df29 = df[df.instrument == ('NI1801' )]

#df25 = pd.concat([df23,df24])
df29['trade_datetime'] = df29.real_trade_date + ' ' + df29.trade_time
df29.index = df29.trade_datetime
df29.index = pd.to_datetime(df29.index)
df29 = df29.sort_index()

df30 = df29[df29.open_close == 1]
print ("Total_trade is ", df30.realized_pl.count())
print ("trade_count ", df30.groupby(df30.index.hour).realized_pl.count())
print ("trade_lots ", df30.groupby(df30.index.hour).lots.sum())

df31 = df30[df30.realized_pl > 0 ]
print ("win_trade is ", df31.realized_pl.count())
print ("profit is ", df31.realized_pl.sum())
print ("win_profit ", df31.groupby(df31.index.hour).realized_pl.sum())
print ("win_count ", df31.groupby(df31.index.hour).realized_pl.count())

df32 = df30[df30.realized_pl < 0]
print ("loss is ", df32.realized_pl.sum())
print ("loss_profit ", df32.groupby(df32.index.hour).realized_pl.sum())
print ("loss_count ", df32.groupby(df32.index.hour).realized_pl.count())

print('lotttssssss', df29.groupby([df29.index.date,df29.open_close]).lots.sum())
# Out:
# Total_trade is  26
# trade_count  trade_datetime
# 0     1
# 9     5
# 10    4
# 11    2
# 13    2
# 14    2
# 21    8
# 22    1
# 23    1
# Name: realized_pl, dtype: int64
# trade_lots  trade_datetime
# 0     1
# 9     5
# 10    5
# 11    2
# 13    2
# 14    2
# 21    9
# 22    1
# 23    1
# Name: lots, dtype: int32
# win_trade is  8
# profit is  16060.0
# win_profit  trade_datetime
# 9     4460.0
# 13    6830.0
# 14    2480.0
# 21    2050.0
# 22     240.0
# Name: realized_pl, dtype: float64
# win_count  trade_datetime
# 9     2
# 13    2
# 14    2
# 21    1
# 22    1
# Name: realized_pl, dtype: int64
# loss is  -3900.0
# loss_profit  trade_datetime
# 0     -300.0
# 9     -420.0
# 10    -980.0
# 11    -610.0
# 21   -1520.0
# 23     -70.0
# Name: realized_pl, dtype: float64
# loss_count  trade_datetime
# 0     1
# 9     3
# 10    4
# 11    2
# 21    7
# 23    1
# Name: realized_pl, dtype: int64
# lotttssssss             open_close
# 2017-08-16  0             3
# ...
