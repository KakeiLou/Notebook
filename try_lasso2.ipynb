# %%
from sklearn import datasets
iris =datasets.load_iris()

# %%
iris.data.shape
# Out:
# (150, 4)

# %%
iris.target.shape
# Out:
# (150,)

# %%
import numpy as np

# %%
np.unique(iris.target)
# Out:
# array([0, 1, 2])

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'],
#       dtype='<U10')

# %%
iris.data
# Out:
# array([[ 5.1,  3.5,  1.4,  0.2],
#        [ 4.9,  3. ,  1.4,  0.2],
#        [ 4.7,  3.2,  1.3,  0.2],
#        [ 4.6,  3.1,  1.5,  0.2],
#        [ 5. ,  3.6,  1.4,  0.2],
#        [ 5.4,  3.9,  1.7,  0.4],
#        [ 4.6,  3.4,  1.4,  0.3],
#        [ 5. ,  3.4,  1.5,  0.2],
#        [ 4.4,  2.9,  1.4,  0.2],
#        [ 4.9,  3.1,  1.5,  0.1],
#        [ 5.4,  3.7,  1.5,  0.2],
#        [ 4.8,  3.4,  1.6,  0.2],
#        [ 4.8,  3. ,  1.4,  0.1],
#        [ 4.3,  3. ,  1.1,  0.1],
#        [ 5.8,  4. ,  1.2,  0.2],
#        [ 5.7,  4.4,  1.5,  0.4],
#        [ 5.4,  3.9,  1.3,  0.4],
#        [ 5.1,  3.5,  1.4,  0.3],
#        [ 5.7,  3.8,  1.7,  0.3],
#        [ 5.1,  3.8,  1.5,  0.3],
#        [ 5.4,  3.4,  1.7,  0.2],
#        [ 5.1,  3.7,  1.5,  0.4],
#        [ 4.6,  3.6,  1. ,  0.2],
#        [ 5.1,  3.3,  1.7,  0.5],
#        [ 4.8,  3.4,  1.9,  0.2],
#        [ 5. ,  3. ,  1.6,  0.2],
#        [ 5. ,  3.4,  1.6,  0.4],
#        [ 5.2,  3.5,  1.5,  0.2],
# ...

# %%
iris.data[:10]
# Out:
# array([[ 5.1,  3.5,  1.4,  0.2],
#        [ 4.9,  3. ,  1.4,  0.2],
#        [ 4.7,  3.2,  1.3,  0.2],
#        [ 4.6,  3.1,  1.5,  0.2],
#        [ 5. ,  3.6,  1.4,  0.2],
#        [ 5.4,  3.9,  1.7,  0.4],
#        [ 4.6,  3.4,  1.4,  0.3],
#        [ 5. ,  3.4,  1.5,  0.2],
#        [ 4.4,  2.9,  1.4,  0.2],
#        [ 4.9,  3.1,  1.5,  0.1]])

# %%
iris.DESCR
# Out:
# 'Iris Plants Database\n====================\n\nNotes\n-----\nData Set Characteristics:\n    :Number of Instances: 150 (50 in each of three classes)\n    :Number of Attributes: 4 numeric, predictive attributes and the class\n    :Attribute Information:\n        - sepal length in cm\n        - sepal width in cm\n        - petal length in cm\n        - petal width in cm\n        - class:\n                - Iris-Setosa\n                - Iris-Versicolour\n                - Iris-Virginica\n    :Summary Statistics:\n\n    ============== ==== ==== ======= ===== ====================\n                    Min  Max   Mean    SD   Class Correlation\n    ============== ==== ==== ======= ===== ====================\n    sepal length:   4.3  7.9   5.84   0.83    0.7826\n    sepal width:    2.0  4.4   3.05   0.43   -0.4194\n    petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)\n    petal width:    0.1  2.5   1.20  0.76     0.9565  (high!)\n    ============== ==== ==== ======= ===== ==========
# ...

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
import pandas as pd 
df = pd.read_hdf('C:\\Users\\Administrator\\Desktop\\mergehsi\\FinishedDataset\\merge_dataset.h5')
df
# Out:
#             amplitude  amplitudeDuration  amplitudeSlope  biggestGain  \
# 2013-05-02      568.0          10.000000       56.800000     0.014093
# 2013-05-03      625.0         214.966667        2.907428     0.019325
# 2013-05-06      559.0          87.983333        6.353476     0.018187
# 2013-05-07      585.0         404.000000        1.448020     0.025476
# 2013-05-08      512.0         347.050000        1.475292     0.014060
# 2013-05-09      547.0           4.950000      110.505051     0.012167
# 2013-05-10      553.0           9.966667       55.484950     0.017937
# 2013-05-13      715.0         338.000000        2.115385     0.013406
# 2013-05-14      671.0         213.983333        3.135758     0.014908
# 2013-05-15      552.0         144.016667        3.832890     0.016553
# 2013-05-16      628.0         117.983333        5.322786     0.016170
# 2013-05-20      630.0         111.950000        5.627512     0.024038
# ...

# %%
df1 = pd.read_hdf('C://Users//Administrator//Desktop//Work//data//hsi_account/account_data_sumprofit.h5')
df1
# Out:
#                     account product  buy_sell  take_price  \
# 2013-05-02 09:15:05   A0002   HSIK3         2     22565.0
# 2013-05-02 09:15:12   A0003   HSIK3         2     22560.0
# 2013-05-02 09:15:53   A0004   HSIK3         2     22554.0
# 2013-05-02 09:15:55   A0005   HSIK3         1     22553.0
# 2013-05-02 09:16:21   A0001   HSIK3         2     22524.0
# 2013-05-02 09:17:08   A0006   HSIK3         1     22535.0
# 2013-05-02 09:18:56   A0007   HSIK3         1     22528.0
# 2013-05-02 09:19:49   A0008   HSIK3         2     22527.0
# 2013-05-02 09:22:39   A0004   HSIK3         2     22513.0
# 2013-05-02 09:22:47   A0009   HSIK3         2     22515.0
# 2013-05-02 09:23:07   A0010   HSIK3         1     22540.0
# 2013-05-02 09:24:09   A0009   HSIK3         2     22552.0
# 2013-05-02 09:24:45   A0011   HSIK3         2     22543.0
# 2013-05-02 09:25:00   A0012   HSIK3         2     22549.0
# 2013-05-02 09:26:24   A0007   HSIK3         1     22542.0
# ...

# %%
df1.index
# Out:
# DatetimeIndex(['2013-05-02 09:15:05', '2013-05-02 09:15:12',
#                '2013-05-02 09:15:53', '2013-05-02 09:15:55',
#                '2013-05-02 09:16:21', '2013-05-02 09:17:08',
#                '2013-05-02 09:18:56', '2013-05-02 09:19:49',
#                '2013-05-02 09:22:39', '2013-05-02 09:22:47',
#                ...
#                '2015-12-30 15:53:05', '2015-12-30 15:56:14',
#                '2015-12-30 15:56:51', '2015-12-30 15:57:40',
#                '2015-12-30 15:58:29', '2015-12-30 15:58:41',
#                '2015-12-30 15:59:19', '2015-12-30 15:59:20',
#                '2015-12-30 15:59:28', '2015-12-30 16:08:16'],
#               dtype='datetime64[ns]', length=402760, freq=None)

# %%
df2 = df1['2013-05-02':'2015-11-30']

# %%
df2
# Out:
#                     account product  buy_sell  take_price  \
# 2013-05-02 09:15:05   A0002   HSIK3         2     22565.0
# 2013-05-02 09:15:12   A0003   HSIK3         2     22560.0
# 2013-05-02 09:15:53   A0004   HSIK3         2     22554.0
# 2013-05-02 09:15:55   A0005   HSIK3         1     22553.0
# 2013-05-02 09:16:21   A0001   HSIK3         2     22524.0
# 2013-05-02 09:17:08   A0006   HSIK3         1     22535.0
# 2013-05-02 09:18:56   A0007   HSIK3         1     22528.0
# 2013-05-02 09:19:49   A0008   HSIK3         2     22527.0
# 2013-05-02 09:22:39   A0004   HSIK3         2     22513.0
# 2013-05-02 09:22:47   A0009   HSIK3         2     22515.0
# 2013-05-02 09:23:07   A0010   HSIK3         1     22540.0
# 2013-05-02 09:24:09   A0009   HSIK3         2     22552.0
# 2013-05-02 09:24:45   A0011   HSIK3         2     22543.0
# 2013-05-02 09:25:00   A0012   HSIK3         2     22549.0
# 2013-05-02 09:26:24   A0007   HSIK3         1     22542.0
# ...

# %%
sr1 = df2.groupby(df2.index.date).profit.sum()
sr1
# Out:
# 2013-05-02    1322.0
# 2013-05-03    1364.0
# 2013-05-06    2261.0
# 2013-05-07      81.0
# 2013-05-08     591.0
# 2013-05-09    1104.0
# 2013-05-10    -625.0
# 2013-05-13     407.0
# 2013-05-14      77.0
# 2013-05-15     210.0
# 2013-05-16    1133.0
# 2013-05-20    -558.0
# 2013-05-21      99.0
# 2013-05-22    -263.0
# 2013-05-23   -1348.0
# 2013-05-24     944.0
# 2013-05-27    1683.0
# 2013-05-28     592.0
# 2013-05-29   -1028.0
# 2013-05-30   -2136.0
# 2013-05-31    1312.0
# 2013-06-03    -401.0
# 2013-06-04     808.0
# 2013-06-05    -917.0
# 2013-06-06    -168.0
# 2013-06-07   -1228.0
# 2013-06-10     673.0
# 2013-06-11     161.0
# 2013-06-13   -1631.0
# 2013-06-14     140.0
#                ...
# 2015-10-19    2592.0
# 2015-10-20    3256.0
# 2015-10-22     866.0
# 2015-10-23     269.0
# 2015-10-26    -443.0
# 2015-10-27     773.0
# 2015-10-28    1758.0
# 2015-10-29     955.0
# 2015-10-30    2478.0
# 2015-11-02    1928.0
# 2015-11-03    2045.0
# 2015-11-04   -2270.0
# ...

# %%
df3 = pd.DataFrame([sr1])

# %%
df3 = df3.T
df3
# Out:
#             profit
# 2013-05-02  1322.0
# 2013-05-03  1364.0
# 2013-05-06  2261.0
# 2013-05-07    81.0
# 2013-05-08   591.0
# 2013-05-09  1104.0
# 2013-05-10  -625.0
# 2013-05-13   407.0
# 2013-05-14    77.0
# 2013-05-15   210.0
# 2013-05-16  1133.0
# 2013-05-20  -558.0
# 2013-05-21    99.0
# 2013-05-22  -263.0
# 2013-05-23 -1348.0
# 2013-05-24   944.0
# 2013-05-27  1683.0
# 2013-05-28   592.0
# 2013-05-29 -1028.0
# 2013-05-30 -2136.0
# 2013-05-31  1312.0
# 2013-06-03  -401.0
# 2013-06-04   808.0
# 2013-06-05  -917.0
# 2013-06-06  -168.0
# 2013-06-07 -1228.0
# 2013-06-10   673.0
# 2013-06-11   161.0
# 2013-06-13 -1631.0
# 2013-06-14   140.0
# ...            ...
# 2015-10-19  2592.0
# 2015-10-20  3256.0
# 2015-10-22   866.0
# 2015-10-23   269.0
# 2015-10-26  -443.0
# 2015-10-27   773.0
# 2015-10-28  1758.0
# 2015-10-29   955.0
# 2015-10-30  2478.0
# 2015-11-02  1928.0
# 2015-11-03  2045.0
# 2015-11-04 -2270.0
# 2015-11-05   379.0
# 2015-11-06  1853.0
# 2015-11-09   906.0
# ...

# %%
df3.index
# Out:
# Index([2013-05-02, 2013-05-03, 2013-05-06, 2013-05-07, 2013-05-08, 2013-05-09,
#        2013-05-10, 2013-05-13, 2013-05-14, 2013-05-15,
#        ...
#        2015-11-17, 2015-11-18, 2015-11-19, 2015-11-20, 2015-11-23, 2015-11-24,
#        2015-11-25, 2015-11-26, 2015-11-27, 2015-11-30],
#       dtype='object', length=637)

# %%
df.index
# Out:
# Index([2013-05-02, 2013-05-03, 2013-05-06, 2013-05-07, 2013-05-08, 2013-05-09,
#        2013-05-10, 2013-05-13, 2013-05-14, 2013-05-15,
#        ...
#        2015-11-17, 2015-11-18, 2015-11-19, 2015-11-20, 2015-11-23, 2015-11-24,
#        2015-11-25, 2015-11-26, 2015-11-27, 2015-11-30],
#       dtype='object', length=637)
