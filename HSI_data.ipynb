# %%
import pandas as pd

df = pd.read_hdf('C:\\Users\\Administrator\\Desktop\\hsi_data\\hsi_finish.h5')

# %%
df
# Out:
#                     instrument type  month  strick_price call_put  trade_date  \
# b'trade_datetime'
# 2014-01-02 09:14:00        HSI    F   1401             0      NaN  2014-01-02
# 2014-01-02 09:14:00        HSI    F   1401             0      NaN  2014-01-02
# 2014-01-02 09:14:00        HSI    F   1401             0      NaN  2014-01-02
# 2014-01-02 09:14:00        HSI    F   1401             0      NaN  2014-01-02
# 2014-01-02 09:14:00        HSI    F   1401             0      NaN  2014-01-02
# 2014-01-02 09:14:00        HSI    F   1401             0      NaN  2014-01-02
# 2014-01-02 09:14:00        HSI    F   1401             0      NaN  2014-01-02
# 2014-01-02 09:14:00        HSI    F   1401             0      NaN  2014-01-02
# 2014-01-02 09:14:00        HSI    F   1401             0      NaN  2014-01-02
# 2014-01-02 09:14:00        HSI    F   1401             0      NaN  2014-01-02
# 2014-01-02 09:14:00        HSI    F   1401             0      NaN  2014-01-02
# ...

# %%
df = df[df.type == 'F']

# %%
df
# Out:
#                     instrument type  month  strick_price call_put  trade_date  \
# b'trade_datetime'
# 2014-01-02 09:14:00        HSI    F   1401             0      NaN  2014-01-02
# 2014-01-02 09:14:00        HSI    F   1401             0      NaN  2014-01-02
# 2014-01-02 09:14:00        HSI    F   1401             0      NaN  2014-01-02
# 2014-01-02 09:14:00        HSI    F   1401             0      NaN  2014-01-02
# 2014-01-02 09:14:00        HSI    F   1401             0      NaN  2014-01-02
# 2014-01-02 09:14:00        HSI    F   1401             0      NaN  2014-01-02
# 2014-01-02 09:14:00        HSI    F   1401             0      NaN  2014-01-02
# 2014-01-02 09:14:00        HSI    F   1401             0      NaN  2014-01-02
# 2014-01-02 09:14:00        HSI    F   1401             0      NaN  2014-01-02
# 2014-01-02 09:14:00        HSI    F   1401             0      NaN  2014-01-02
# 2014-01-02 09:14:00        HSI    F   1401             0      NaN  2014-01-02
# ...

# %%
df.drop('strick_price', axis=1, inplace=True)
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#                     instrument type  month call_put  trade_date trade_time  \
# b'trade_datetime'
# 2014-01-02 09:14:00        HSI    F   1401      NaN  2014-01-02   09:14:00
# 2014-01-02 09:14:00        HSI    F   1401      NaN  2014-01-02   09:14:00
# 2014-01-02 09:14:00        HSI    F   1401      NaN  2014-01-02   09:14:00
# 2014-01-02 09:14:00        HSI    F   1401      NaN  2014-01-02   09:14:00
# 2014-01-02 09:14:00        HSI    F   1401      NaN  2014-01-02   09:14:00
# 2014-01-02 09:14:00        HSI    F   1401      NaN  2014-01-02   09:14:00
# 2014-01-02 09:14:00        HSI    F   1401      NaN  2014-01-02   09:14:00
# 2014-01-02 09:14:00        HSI    F   1401      NaN  2014-01-02   09:14:00
# 2014-01-02 09:14:00        HSI    F   1401      NaN  2014-01-02   09:14:00
# 2014-01-02 09:14:00        HSI    F   1401      NaN  2014-01-02   09:14:00
# 2014-01-02 09:14:00        HSI    F   1401      NaN  2014-01-02   09:14:00
# ...

# %%
df.drop(['call_put','trade_type'], axis=1, inplace=True)
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#                     instrument type  month  trade_date trade_time    price  \
# b'trade_datetime'
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# 2014-01-02 09:14:00        HSI    F   1401  2014-01-02   09:14:00  23414.0
# ...

# %%
df.to_hdf('his_simplified.h5','df')

# %%
df2 = df[df]
