# %%
import pandas as pd

# %%
# %matplotlib inline

# %%
df = pd.read_hdf('C://Users//Administrator//Desktop//CTA_trade_detail/trade_detail_0095181006.h5')
df
# Out:
#     instrument  order_no trade_time  direction  order_price  lots  turnover  \
# 0       CS1709  10149496   09:00:04          1       2017.0     5  100850.0
# 1       CS1709  10166537   09:01:47          1       2017.0     2   40340.0
# 2       CS1709  10166538   09:01:47          1       2017.0     1   20170.0
# 3       CS1709  10166539   09:01:47          1       2017.0     1   20170.0
# 4       CS1709  10166540   09:01:47          1       2017.0     1   20170.0
# 5       CS1709  10166717   09:01:50          1       2017.0     5  100850.0
# 6        FG709  00929907   09:02:43          1       1232.0     3   73920.0
# 7        FG709  00936894   09:03:12          1       1234.0     1   24680.0
# 8        FG709  00936896   09:03:12          1       1234.0     1   24680.0
# 9       CS1709  10190775   09:07:16          1       2013.0     3   60390.0
# 10      CS1709  10201419   09:09:27          1       2014.0     2   40280.0
# ...

# %%
df.fee.sum()
# Out:
# 102089.69000000186

# %%
df.realized_pl.sum()
# Out:
# 124970.0

# %%
df.index = df.real_trade_date

# %%
df.index = df.real_trade_date
df.index = pd.to_datetime(df.index)
df.index
# Out:
# DatetimeIndex(['2017-04-17', '2017-04-17', '2017-04-17', '2017-04-17',
#                '2017-04-17', '2017-04-17', '2017-04-17', '2017-04-17',
#                '2017-04-17', '2017-04-17',
#                ...
#                '2017-10-16', '2017-10-16', '2017-10-16', '2017-10-16',
#                '2017-10-16', '2017-10-16', '2017-10-16', '2017-10-16',
#                '2017-10-16', '2017-10-16'],
#               dtype='datetime64[ns]', name='real_trade_date', length=20391, freq=None)

# %%
df
# Out:
#                 instrument  order_no trade_time  direction  order_price  lots  \
# real_trade_date
# 2017-04-17          CS1709  10149496   09:00:04          1       2017.0     5
# 2017-04-17          CS1709  10166537   09:01:47          1       2017.0     2
# 2017-04-17          CS1709  10166538   09:01:47          1       2017.0     1
# 2017-04-17          CS1709  10166539   09:01:47          1       2017.0     1
# 2017-04-17          CS1709  10166540   09:01:47          1       2017.0     1
# 2017-04-17          CS1709  10166717   09:01:50          1       2017.0     5
# 2017-04-17           FG709  00929907   09:02:43          1       1232.0     3
# 2017-04-17           FG709  00936894   09:03:12          1       1234.0     1
# 2017-04-17           FG709  00936896   09:03:12          1       1234.0     1
# 2017-04-17          CS1709  10190775   09:07:16          1       2013.0     3
# 2017-04-17          CS1709  10201419   09:09:27          1       2014.0     2
# ...

# %%
sr = df.groupby(df.index.month).fee.sum()
sr
# Out:
# real_trade_date
# 4     10784.12
# 5     18824.42
# 6     26325.94
# 7     19272.18
# 8      9763.74
# 9     14115.26
# 10     3004.03
# Name: fee, dtype: float64

# %%
sr18 = df.groupby(df.index.month).realized_pl.sum()
sr18
# Out:
# real_trade_date
# 4     -5865.0
# 5     48860.0
# 6     -7645.0
# 7    -14760.0
# 8     36105.0
# 9     63170.0
# 10     5105.0
# Name: realized_pl, dtype: float64

# %%
sr18.plot()

# %%
sr19 = df.groupby(df.index.month).count1.sum()
sr19
# Out:
# real_trade_date
# 4     1853
# 5     3984
# 6     4488
# 7     3500
# 8     2335
# 9     3423
# 10     808
# Name: count1, dtype: int64

# %%
sr19.plot()

# %%
sr/sr19
# Out:
# real_trade_date
# 4     5.819817
# 5     4.725005
# 6     5.865851
# 7     5.506337
# 8     4.181473
# 9     4.123652
# 10    3.717859
# dtype: float64

# %%
sr[:7].mean()
# Out:
# 14584.241428571446

# %%
sr.plot()

# %%
df1 = pd.read_hdf('C:/Users/Administrator/Desktop/Work/data/CTA_trade_detail_all/trade_detail_001810115002.h5')
df1
# Out:
#     instrument  order_no trade_time  direction  order_price  lots  turnover  \
# 0        C1709  10397523   13:31:28          1       1670.0     5   83500.0
# 1        C1709  10424539   13:42:18          1       1669.0     3   50070.0
# 2        MA709  01736313   13:47:54          0       2502.0     1   25020.0
# 3        MA709  01736315   13:47:54          0       2502.0     2   50040.0
# 4        MA709  01743943   13:49:44          0       2501.0     2   50020.0
# 5        C1709  10438422   13:50:38          0       1673.0     8  133840.0
# 6        L1709  30479260   13:52:29          0       9200.0     2   92000.0
# 7       RU1709  01716175   13:53:04          0      13560.0     1  135600.0
# 8        MA709  01772932   13:57:01          0       2501.0     3   75030.0
# 9        MA709  01791156   14:00:51          1       2496.0     1   24960.0
# 10      RU1709  01769795   14:05:35          1      13515.0     1  135150.0
# ...

# %%
df1['count1'] = 1

# %%
df1.fee.sum()
# Out:
# 33870.32000000001

# %%
df1.realized_pl.sum()
# Out:
# 98400.0

# %%
df1.index = df1.real_trade_date
df1.index = pd.to_datetime(df1.index)
df1.index
# Out:
# DatetimeIndex(['2017-07-17', '2017-07-17', '2017-07-17', '2017-07-17',
#                '2017-07-17', '2017-07-17', '2017-07-17', '2017-07-17',
#                '2017-07-17', '2017-07-17',
#                ...
#                '2017-10-16', '2017-10-16', '2017-10-16', '2017-10-16',
#                '2017-10-16', '2017-10-16', '2017-10-16', '2017-10-16',
#                '2017-10-16', '2017-10-16'],
#               dtype='datetime64[ns]', name='real_trade_date', length=8061, freq=None)

# %%
sr1 = df1.groupby(df1.index.month).fee.sum()
sr1
# Out:
# real_trade_date
# 7      8579.04
# 8      9356.66
# 9     13054.00
# 10     2880.62
# Name: fee, dtype: float64

# %%
sr1.mean()
# Out:
# 8467.580000000058

# %%
sr1.plot()

# %%
sr20 = df1.groupby(df1.index.month).count1.sum()
sr20
# Out:
# real_trade_date
# 7     1719
# 8     2265
# 9     3262
# 10     815
# Name: count1, dtype: int64

# %%
sr20.plot()

# %%
sr1/sr20
# Out:
# real_trade_date
# 7     4.990716
# 8     4.130976
# 9     4.001839
# 10    3.534503
# dtype: float64

# %%
sr21 = df1.groupby(df1.index.month).realized_pl.sum()
sr21
# Out:
# real_trade_date
# 7    -18580.0
# 8     34880.0
# 9     77140.0
# 10     4960.0
# Name: realized_pl, dtype: float64

# %%
sr21.plot()

# %%
df2 = pd.read_hdf('C://Users//Administrator//Desktop//CTA_trade_detail/trade_detail_007738030022.h5')
df2
# Out:
#      instrument  order_no trade_time  direction  order_price  lots  turnover  \
# 0         M1705  10545298   10:05:32          0       2909.0     1   29090.0
# 1         M1705  10548973   10:05:59          1       2912.0     1   29120.0
# 2         RM705  01513316   10:31:32          0       2441.0     5  122050.0
# 3         M1705  10612069   10:42:27          0       2912.0     1   29120.0
# 4         M1705  10612494   10:42:45          0       2913.0     1   29130.0
# 5         M1705  10613334   10:43:10          0       2912.0     1   29120.0
# 6         M1705  10659448   10:59:45          1       2914.0     2   58280.0
# 7         M1705  10659449   10:59:45          1       2914.0     1   29140.0
# 8         RM705  01630287   11:01:03          1       2449.0     2   48980.0
# 9         RM705  01630519   11:01:05          1       2449.0     1   24490.0
# 10        RM705  01630521   11:01:05          1       2449.0     1   24490.0
# ...

# %%
df2['count1'] = 1 
df2
# Out:
#                 instrument  order_no trade_time  direction  order_price  lots  \
# real_trade_date
# 2016-12-05           M1705  10545298   10:05:32          0       2909.0     1
# 2016-12-05           M1705  10548973   10:05:59          1       2912.0     1
# 2016-12-05           RM705  01513316   10:31:32          0       2441.0     5
# 2016-12-05           M1705  10612069   10:42:27          0       2912.0     1
# 2016-12-05           M1705  10612494   10:42:45          0       2913.0     1
# 2016-12-05           M1705  10613334   10:43:10          0       2912.0     1
# 2016-12-05           M1705  10659448   10:59:45          1       2914.0     2
# 2016-12-05           M1705  10659449   10:59:45          1       2914.0     1
# 2016-12-05           RM705  01630287   11:01:03          1       2449.0     2
# 2016-12-05           RM705  01630519   11:01:05          1       2449.0     1
# 2016-12-05           RM705  01630521   11:01:05          1       2449.0     1
# ...

# %%
df2.fee.sum()
# Out:
# 326458.11000001995

# %%
df2.realized_pl.sum()
# Out:
# 427755.0

# %%
df2.index = df2.real_trade_date
df2.index = pd.to_datetime(df2.index)
df2.index
# Out:
# DatetimeIndex(['2016-12-05', '2016-12-05', '2016-12-05', '2016-12-05',
#                '2016-12-05', '2016-12-05', '2016-12-05', '2016-12-05',
#                '2016-12-05', '2016-12-05',
#                ...
#                '2017-07-21', '2017-07-24', '2017-07-24', '2017-07-24',
#                '2017-07-24', '2017-07-24', '2017-07-24', '2017-07-24',
#                '2017-07-24', '2017-07-24'],
#               dtype='datetime64[ns]', name='real_trade_date', length=42019, freq=None)

# %%
sr2 = df2.groupby([df2.index.year, df2.index.month]).fee.sum()
sr2
# Out:
# real_trade_date  real_trade_date
# 2016             12                 93206.27
# 2017             1                  64399.34
#                  2                  47192.01
#                  3                  36445.18
#                  4                  21961.71
#                  5                  19828.49
#                  6                  28062.69
#                  7                  15362.42
# Name: fee, dtype: float64

# %%
sr2.mean()
# Out:
# 40807.26374999989

# %%
sr2.plot()

# %%
sr3 = df2.groupby([df2.index.year, df2.index.month]).realized_pl.sum()
sr3
# Out:
# real_trade_date  real_trade_date
# 2016             12                 119510.0
# 2017             1                  120330.0
#                  2                   67860.0
#                  3                   73225.0
#                  4                  -10085.0
#                  5                   53910.0
#                  6                    2440.0
#                  7                     565.0
# Name: realized_pl, dtype: float64

# %%
sr3.plot()

# %%
sr4 = df2.groupby([df2.index.year, df2.index.month]).count1.sum()
sr4
# Out:
# real_trade_date  real_trade_date
# 2016             12                 8320
# 2017             1                  6893
#                  2                  5488
#                  3                  5751
#                  4                  4250
#                  5                  4073
#                  6                  4600
#                  7                  2644
# Name: count1, dtype: int64

# %%
sr4.plot()

# %%
sr2/sr4
# Out:
# real_trade_date  real_trade_date
# 2016             12                 11.202677
# 2017             1                   9.342716
#                  2                   8.599127
#                  3                   6.337190
#                  4                   5.167461
#                  5                   4.868276
#                  6                   6.100585
#                  7                   5.810295
# dtype: float64

# %%
df3 = pd.read_hdf('C://Users//Administrator//Desktop//CTA_trade_detail/trade_detail_0158120301609.h5')
df3
# Out:
#     instrument  order_no trade_time  direction  order_price  lots  turnover  \
# 0        C1709  10183266   08:59:00          1       1637.0     3   49110.0
# 1        C1709  10189757   09:00:50          1       1637.0     3   49110.0
# 2        C1709  10200759   09:03:14          1       1634.0     3   49020.0
# 3        C1709  10201981   09:03:38          1       1635.0     2   32700.0
# 4        P1709  10202101   09:03:40          1       5234.0     1   52340.0
# 5        P1709  10206711   09:05:04          1       5234.0     1   52340.0
# 6        P1709  10207160   09:05:10          1       5236.0     1   52360.0
# 7        C1709  10216909   09:07:40          1       1632.0     3   48960.0
# 8        Y1709  10217145   09:07:48          1       5972.0     1   59720.0
# 9        Y1709  10218078   09:08:09          1       5972.0     1   59720.0
# 10       C1709  10222090   09:09:44          1       1633.0     4   65320.0
# ...

# %%
df3['count1' ]= 1

# %%
df3.fee.sum()
# Out:
# 96222.41999998975

# %%
df3.realized_pl.sum()
# Out:
# 123565.0

# %%
df3.index = df3.real_trade_date
df3.index = pd.to_datetime(df3.index)
df3.index
# Out:
# DatetimeIndex(['2017-04-18', '2017-04-18', '2017-04-18', '2017-04-18',
#                '2017-04-18', '2017-04-18', '2017-04-18', '2017-04-18',
#                '2017-04-18', '2017-04-18',
#                ...
#                '2017-10-16', '2017-10-16', '2017-10-16', '2017-10-16',
#                '2017-10-16', '2017-10-16', '2017-10-16', '2017-10-16',
#                '2017-10-16', '2017-10-16'],
#               dtype='datetime64[ns]', name='real_trade_date', length=20076, freq=None)

# %%
sr5 = df3.groupby(df3.index.month).fee.sum()
sr5
# Out:
# real_trade_date
# 4      8013.43
# 5     18334.29
# 6     25208.01
# 7     18778.53
# 8      9432.31
# 9     13542.33
# 10     2913.52
# Name: fee, dtype: float64

# %%
sr5.mean()
# Out:
# 13746.060000000098

# %%
sr5.plot()

# %%
sr22 = df3.groupby(df3.index.month).realized_pl.sum()
sr22
# Out:
# real_trade_date
# 4    -10000.0
# 5     47675.0
# 6      -890.0
# 7    -14605.0
# 8     34675.0
# 9     61395.0
# 10     5315.0
# Name: realized_pl, dtype: float64

# %%
sr22.plot()

# %%
sr23 = df3.groupby(df3.index.month).count1.sum()
sr23
# Out:
# real_trade_date
# 4     1820
# 5     3992
# 6     4357
# 7     3452
# 8     2289
# 9     3380
# 10     786
# Name: count1, dtype: int64

# %%
sr23.plot()

# %%
sr5/sr23
# Out:
# real_trade_date
# 4     4.402984
# 5     4.592758
# 6     5.785635
# 7     5.439899
# 8     4.120712
# 9     4.006607
# 10    3.706768
# dtype: float64

# %%
df4 = pd.read_hdf('C://Users//Administrator//Desktop//CTA_trade_detail/trade_detail_0158120301760.h5')
df4
# Out:
#     instrument  order_no trade_time  direction  order_price  lots  turnover  \
# 0        MA709  00801137   09:02:09          0       2484.0     3   74520.0
# 1        MA709  00825297   09:04:23          0       2484.0     2   49680.0
# 2        Y1801  10235544   09:11:30          0       6288.0     1   62880.0
# 3        MA709  00962920   09:16:36          0       2481.0     3   74430.0
# 4        MA709  00974229   09:17:43          1       2477.0     1   24770.0
# 5        MA709  00974231   09:17:43          1       2477.0     1   24770.0
# 6        MA709  00974636   09:17:45          1       2476.0     1   24760.0
# 7        MA709  00974637   09:17:45          1       2476.0     2   49520.0
# 8        MA709  00974638   09:17:45          1       2476.0     3   74280.0
# 9        MA709  01013830   09:21:19          1       2470.0     3   74100.0
# 10      BU1709  01113000   09:22:55          1       2636.0     4  105440.0
# ...

# %%
df4['count1'] = 1

# %%
df4.fee.sum()
# Out:
# 29020.380000000598

# %%
df4.realized_pl.sum()
# Out:
# 89890.0

# %%
df4.index = df4.real_trade_date
df4.index = pd.to_datetime(df4.index)
df4.index
# Out:
# DatetimeIndex(['2017-07-26', '2017-07-26', '2017-07-26', '2017-07-26',
#                '2017-07-26', '2017-07-26', '2017-07-26', '2017-07-26',
#                '2017-07-26', '2017-07-26',
#                ...
#                '2017-10-16', '2017-10-16', '2017-10-16', '2017-10-16',
#                '2017-10-16', '2017-10-16', '2017-10-16', '2017-10-16',
#                '2017-10-16', '2017-10-16'],
#               dtype='datetime64[ns]', name='real_trade_date', length=7141, freq=None)

# %%
sr6 = df4.groupby(df4.index.month).fee.sum()
sr6
# Out:
# real_trade_date
# 7      3099.90
# 8      9437.86
# 9     13569.08
# 10     2913.54
# Name: fee, dtype: float64

# %%
sr6.mean()
# Out:
# 7255.094999999985

# %%
sr6.plot()

# %%
sr7 = df4.groupby(df4.index.month).realized_pl.sum()
sr7
# Out:
# real_trade_date
# 7    -10705.0
# 8     34920.0
# 9     60760.0
# 10     4915.0
# Name: realized_pl, dtype: float64

# %%
sr7.plot()

# %%
sr8 = df4.groupby(df4.index.month).count1.sum()
sr8
# Out:
# real_trade_date
# 7      562
# 8     2295
# 9     3451
# 10     833
# Name: count1, dtype: int64

# %%
sr8.plot()

# %%
sr6/sr8
# Out:
# real_trade_date
# 7     5.515836
# 8     4.112357
# 9     3.931927
# 10    3.497647
# dtype: float64

# %%
df5 = pd.read_hdf('C://Users//Administrator//Desktop//CTA_trade_detail/trade_detail_0158120350655.h5')
df5
# Out:
#     instrument  order_no trade_time  direction  order_price  lots  turnover  \
# 0        CF709  00939988   09:05:49          1      15480.0     1   77400.0
# 1        TA709  00949197   09:06:36          1       5162.0     2   51620.0
# 2        TA709  00954800   09:07:09          1       5164.0     1   25820.0
# 3        TA709  00954873   09:07:10          1       5164.0     1   25820.0
# 4        TA709  00955002   09:07:11          1       5164.0     2   51640.0
# 5        TA709  01214170   09:35:18          1       5138.0     1   25690.0
# 6       CU1705  00888209   09:43:18          0      47440.0     1  237200.0
# 7       CS1709  10331693   09:50:47          1       2054.0     2   41080.0
# 8       CS1709  10333175   09:51:50          1       2055.0     2   41100.0
# 9        C1709  10335992   09:53:56          1       1674.0     2   33480.0
# 10      CS1709  10338455   09:55:25          1       2056.0     1   20560.0
# ...

# %%
df5['count1'] = 1

# %%
df5.fee.sum()
# Out:
# 82401.45999999066

# %%
df5.realized_pl.sum()
# Out:
# 10560.0

# %%
df5.index = df5.real_trade_date
df5.index = pd.to_datetime(df5.index)
df5.index
# Out:
# DatetimeIndex(['2017-03-30', '2017-03-30', '2017-03-30', '2017-03-30',
#                '2017-03-30', '2017-03-30', '2017-03-30', '2017-03-30',
#                '2017-03-30', '2017-03-30',
#                ...
#                '2017-07-28', '2017-07-28', '2017-07-28', '2017-07-28',
#                '2017-07-28', '2017-07-28', '2017-07-28', '2017-07-28',
#                '2017-07-28', '2017-07-28'],
#               dtype='datetime64[ns]', name='real_trade_date', length=15950, freq=None)

# %%
sr9 = df5.groupby(df5.index.month).fee.sum()
sr9
# Out:
# real_trade_date
# 3     1129.13
# 4    20832.93
# 5    18327.08
# 6    25253.74
# 7    16858.58
# Name: fee, dtype: float64

# %%
sr9.plot()

# %%
sr9.mean()
# Out:
# 16480.292000000114

# %%
sr10 = df5.groupby(df5.index.month).realized_pl.sum()
sr10
# Out:
# real_trade_date
# 3     2270.0
# 4   -30210.0
# 5    48025.0
# 6    -2120.0
# 7    -7405.0
# Name: realized_pl, dtype: float64

# %%
sr10.sum()
# Out:
# 10560.0

# %%
sr10.plot()

# %%
sr11 = df5.groupby(df5.index.month).count1.sum()
sr11
# Out:
# real_trade_date
# 3     294
# 4    4170
# 5    3971
# 6    4399
# 7    3116
# Name: count1, dtype: int64

# %%
sr11.plot()

# %%
sr9/sr11
# Out:
# real_trade_date
# 3    3.840578
# 4    4.995906
# 5    4.615230
# 6    5.740791
# 7    5.410327
# dtype: float64

# %%
df6 = pd.read_hdf('C://Users//Administrator//Desktop//CTA_trade_detail/trade_detail_020916808183.h5')
df6
# Out:
#     instrument  order_no trade_time  direction  order_price  lots  turnover  \
# 0        SM709  00684579   08:59:00          0       6486.0     3   97290.0
# 1       JD1801  10129066   09:00:26          0       3846.0     2   76920.0
# 2        SR709  00697290   09:00:38          1       6576.0     2  131520.0
# 3        SR709  00708144   09:01:48          1       6577.0     2  131540.0
# 4        SM709  00709704   09:02:03          0       6474.0     2   64740.0
# 5        SR709  00731710   09:04:53          0       6582.0     2  131640.0
# 6        SM709  00735066   09:05:21          0       6474.0     2   64740.0
# 7        SM709  00741919   09:06:02          1       6464.0     2   64640.0
# 8        SM709  00741936   09:06:02          1       6464.0     1   32320.0
# 9        SR709  00748510   09:06:48          1       6581.0     3  197430.0
# 10      JD1801  10156340   09:06:55          0       3855.0     1   38550.0
# ...

# %%
df6['count1'] = 1

# %%
df6.fee.sum()
# Out:
# 30320.97000000018

# %%
df6.realized_pl.sum()
# Out:
# -13935.0

# %%
df6.index = df6.real_trade_date
df6.index = pd.to_datetime(df6.index)
df6.index
# Out:
# DatetimeIndex(['2017-06-06', '2017-06-06', '2017-06-06', '2017-06-06',
#                '2017-06-06', '2017-06-06', '2017-06-06', '2017-06-06',
#                '2017-06-06', '2017-06-06',
#                ...
#                '2017-07-07', '2017-07-07', '2017-07-07', '2017-07-07',
#                '2017-07-07', '2017-07-07', '2017-07-07', '2017-07-07',
#                '2017-07-07', '2017-07-07'],
#               dtype='datetime64[ns]', name='real_trade_date', length=4507, freq=None)

# %%
sr12 = df6.groupby(df6.index.month).fee.sum()
sr12
# Out:
# real_trade_date
# 6    25415.19
# 7     4905.78
# Name: fee, dtype: float64

# %%
sr13 = df6.groupby(df6.index.month).realized_pl.sum()
sr13
# Out:
# real_trade_date
# 6     4340.0
# 7   -18275.0
# Name: realized_pl, dtype: float64

# %%
sr14 = df6.groupby(df6.index.month).count1.sum()
sr14
# Out:
# real_trade_date
# 6    3820
# 7     687
# Name: count1, dtype: int64

# %%
sr12/sr14
# Out:
# real_trade_date
# 6    6.653191
# 7    7.140873
# dtype: float64

# %%
df7 = pd.read_hdf('C://Users//Administrator//Desktop//CTA_trade_detail/trade_detail_022815500011.h5')
df7
# Out:
#     instrument  order_no trade_time  direction  order_price  lots  turnover  \
# 0        M1801  10216620   09:00:18          1       2844.0     3   85320.0
# 1        M1801  10216641   09:00:18          1       2844.0     2   56880.0
# 2        M1801  10221256   09:01:04          1       2846.0     3   85380.0
# 3       JD1709  10240238   09:06:24          0       3976.0     3  119280.0
# 4       JD1709  10242496   09:07:07          0       3975.0     3  119250.0
# 5       JD1709  10244981   09:07:51          0       3974.0     1   39740.0
# 6        MA801  00796142   09:08:35          1       2476.0     3   74280.0
# 7       JD1709  10253872   09:11:06          1       3968.0     3  119040.0
# 8       JD1709  10254164   09:11:18          1       3969.0     3  119070.0
# 9       JD1709  10255756   09:12:00          1       3967.0     1   39670.0
# 10      PP1801  30211071   09:12:29          1       8500.0     3  127500.0
# ...

# %%
df7['2017-07']
# Out:
#                 instrument  order_no trade_time  direction  order_price  lots  \
# real_trade_date
# 2017-07-28           M1801  10216620   09:00:18          1       2844.0     3
# 2017-07-28           M1801  10216641   09:00:18          1       2844.0     2
# 2017-07-28           M1801  10221256   09:01:04          1       2846.0     3
# 2017-07-28          JD1709  10240238   09:06:24          0       3976.0     3
# 2017-07-28          JD1709  10242496   09:07:07          0       3975.0     3
# 2017-07-28          JD1709  10244981   09:07:51          0       3974.0     1
# 2017-07-28           MA801  00796142   09:08:35          1       2476.0     3
# 2017-07-28          JD1709  10253872   09:11:06          1       3968.0     3
# 2017-07-28          JD1709  10254164   09:11:18          1       3969.0     3
# 2017-07-28          JD1709  10255756   09:12:00          1       3967.0     1
# 2017-07-28          PP1801  30211071   09:12:29          1       8500.0     3
# ...

# %%
df7['count1'] = 1

# %%
df7.fee.sum()
# Out:
# 23595.410000000433

# %%
df7.realized_pl.sum()
# Out:
# 37790.0

# %%
df7.index = df7.real_trade_date
df7.index = pd.to_datetime(df7.index)
df7.index
# Out:
# DatetimeIndex(['2017-07-28', '2017-07-28', '2017-07-28', '2017-07-28',
#                '2017-07-28', '2017-07-28', '2017-07-28', '2017-07-28',
#                '2017-07-28', '2017-07-28',
#                ...
#                '2017-10-16', '2017-10-16', '2017-10-16', '2017-10-16',
#                '2017-10-16', '2017-10-16', '2017-10-16', '2017-10-16',
#                '2017-10-16', '2017-10-16'],
#               dtype='datetime64[ns]', name='real_trade_date', length=5090, freq=None)

# %%
sr15 = df7.groupby(df7.index.month).fee.sum()
sr15
# Out:
# real_trade_date
# 7      3874.16
# 8      3130.59
# 9     13653.01
# 10     2937.65
# Name: fee, dtype: float64

# %%
sr15.plot()

# %%
sr16 = df7.groupby(df7.index.month).realized_pl.sum()
sr16
# Out:
# real_trade_date
# 7     -4275.0
# 8    -25850.0
# 9     62760.0
# 10     5155.0
# Name: realized_pl, dtype: float64

# %%
sr16.plot()

# %%
sr17 = df7.groupby(df7.index.month).count1.sum()
sr17
# Out:
# real_trade_date
# 7      179
# 8      693
# 9     3404
# 10     814
# Name: count1, dtype: int64

# %%
sr17.plot()

# %%
sr15/sr17
# Out:
# real_trade_date
# 7     21.643352
# 8      4.517446
# 9      4.010873
# 10     3.608907
# dtype: float64
