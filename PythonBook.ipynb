# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_hdf('C:\\Users\\Administrator\\Desktop\\Work\\data\\IC1712\\IC1712.CFE.min.h5')

# %%
df
# Out:
#                        open    high     low   close  volume      amount  \
# 2017-04-24 09:30:00  6044.6  6068.8  6044.6  6068.8    11.0  13314840.0
# 2017-04-24 09:31:00  6068.8  6068.8  6036.0  6036.0     3.0   3624840.0
# 2017-04-24 09:32:00  6036.0  6046.8  6036.0  6046.8     1.0   1209360.0
# 2017-04-24 09:33:00  6046.8  6046.8  6022.4  6022.4     1.0   1204480.0
# 2017-04-24 09:34:00  6022.4  6022.4  6022.4  6022.4     0.0         0.0
# 2017-04-24 09:35:00  6022.4  6022.4  6004.2  6004.2     1.0   1200840.0
# 2017-04-24 09:36:00  6005.0  6005.0  5969.6  5969.6     5.0   5995720.0
# 2017-04-24 09:37:00  5969.6  6001.8  5969.6  5988.0     4.0   4789440.0
# 2017-04-24 09:38:00  5988.0  5988.0  5988.0  5988.0     0.0         0.0
# 2017-04-24 09:39:00  5988.0  6000.0  5988.0  5998.6     2.0   2399720.0
# 2017-04-24 09:40:00  5998.6  5998.6  5998.6  5998.6     0.0         0.0
# 2017-04-24 09:41:00  5998.6  5998.6  5988.0  5988.0     4.0   4792960.0
# ...

# %%
def get_counts(sequence):
    counts = {}
    for x in sequence:
        if x in counts:
            counts[x] += 1
        else:
            counts[x] = 1
    return counts

# %%
counts = get_counts(df.open)

# %%
counts[6625.8]
# Out:
# 2

# %%
len(df.open)
# Out:
# 28528

# %%
(counts[6626.2]/len(df.open))
# Out:
# 7.010656197420079e-05

# %%
from collections import Counter

# %%
counts = Counter(df.high)

# %%
counts.most_common(3)
# Out:
# [(5875.0, 80), (5870.0, 66), (5600.0, 65)]

# %%
open_counts = df['open'].value_counts()

# %%
open_counts[:1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_slice_bound(self, label, side, kind)
#    3434             try:
# -> 3435                 return self._searchsorted_monotonic(label, side)
#    3436             except ValueError:
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _searchsorted_monotonic(self, label, side)
#    3393
# -> 3394         raise ValueError('index must be monotonic increasing or decreasing')
#    3395
#
# ValueError: index must be monotonic increasing or decreasing
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-0fd26ea92203> in <module>()
# ----> 1 open_counts[:1]
#
# ...
